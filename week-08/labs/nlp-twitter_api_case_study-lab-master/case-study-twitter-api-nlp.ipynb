# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # NLP Using the Twitter API: Guided Lab
#
# _Authors: Dave Yerrington (SF)_
#
# ---
#
#
# <img src="https://snag.gy/RNAEgP.jpg" width="600">
#
# ### Can We Correctly Identify Which of These Men Tweeted What?
#
# > *Note: This lab is intended to be a guided lab until the independent practice questions.*

# %% [markdown]
# ## Goals
# ---
#
# We're going to attempt to classify whether a tweet comes from Donald Trump or Bernie Sanders. This lab involves multiple steps:
# - Create a developer account on Twitter.
# - Create a method to pull a list of tweets from the Twitter API.
# - Perform proper preprocessing on our text.
# - Engineer sentiment features in our data set using `TextBlob`.
# - Explore supervised classification techniques.

# %% [markdown]
# ## Twitter API Developer Registration
# ---
#
# If you haven't registered for a Twitter account, do so now in order to have a developer account for this lab.
#
# [Twitter Rest API](https://dev.twitter.com/rest/public)

# %% [markdown]
# ## Create an App
#
# ---
#
# ![](https://snag.gy/HPBQbJ.jpg)
#
# Go to Twitter and register an app: [apps.twitter.com](https://apps.twitter.com/).
#
# > **Note**: For the required website field, you can put a placeholder.
#
# After you set up your application, you’ll only need to reference the corresponding keys Twitter generates for it. These are the keys that we'll use with our application to communicate with the Twitter API.

# %% [markdown]
# ## Install Python Twitter API Library
#
# ---
#
# Someone was nice enough to build a Python library for us, which makes pulling tweets simple: We only need to plug in our keys to start collecting data. The library we'll be using is provided by [Python Twitter Tools](http://mike.verdone.ca/twitter/).
#
# To install it, just run the next frame (there is no conda package).

# %%
# !pip install twitter python-twitter
# Out:
# Collecting twitter
#   Downloading https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl (54kB)
# Collecting python-twitter
#   Downloading https://files.pythonhosted.org/packages/e6/2c/9fc6565b57ce6f3cc8e20b6c4bde8960dd0857629d41654bce46a6dd0bf9/python_twitter-3.4.2-py2.py3-none-any.whl (61kB)
# Requirement already satisfied: requests in c:\users\samson\appdata\local\continuum\anaconda2\lib\site-packages (from python-twitter)
# Collecting requests-oauthlib (from python-twitter)
#   Downloading https://files.pythonhosted.org/packages/94/e7/c250d122992e1561690d9c0f7856dadb79d61fd4bdd0e598087dce607f6c/requests_oauthlib-1.0.0-py2.py3-none-any.whl
# Collecting future (from python-twitter)
#   Downloading https://files.pythonhosted.org/packages/00/2b/8d082ddfed935f3608cc61140df6dcbf0edea1bc3ab52fb6c29ae3e81e85/future-0.16.0.tar.gz (824kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\samson\appdata\local\continuum\anaconda2\lib\site-packages (from requests->python-twitter)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\samson\appdata\local\continuum\anaconda2\lib\site-packages (from requests->python-twitter)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\samson\appdata\local\continuum\anaconda2\lib\site-packages (from requests->python-twitter)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samson\appdata\local\continuum\anaconda2\lib\site-packages (from requests->python-twitter)
# Collecting oauthlib>=0.6.2 (from requests-oauthlib->python-twitter)
#   Downloading https://files.pythonhosted.org/packages/e6/d1/ddd9cfea3e736399b97ded5c2dd62d1322adef4a72d816f1ed1049d6a179/oauthlib-2.1.0-py2.py3-none-any.whl (121kB)
# Building wheels for collected packages: future
#   Running setup.py bdist_wheel for future: started
#   Running setup.py bdist_wheel for future: finished with status 'done'
#   Stored in directory: C:\Users\Samson\AppData\Local\pip\Cache\wheels\bf\c9\a3\c538d90ef17cf7823fa51fc701a7a7a910a80f6a405bf15b1a
# Successfully built future
# Installing collected packages: twitter, oauthlib, requests-oauthlib, future, python-twitter
# Successfully installed future-0.16.0 oauthlib-2.1.0 python-twitter-3.4.2 requests-oauthlib-1.0.0 twitter-1.18.0
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Some Twitter Rules
# ---
#
# **Twitter notifies you that your requests have a rate limit.**
#
# > When using application-only authentication, rate limits are determined globally for the entire application. If a method allows for 15 requests per rate-limit window, then it allows you to make 15 requests per window on behalf of your application. This limit is considered separately from per-user limits. https://dev.twitter.com/rest/public/rate-limiting
#
# Here's a quick overview of Twitter's rules:
#
# ![](https://snag.gy/yJ6vIH.jpg)

# %% [markdown]
# ## About Those Keys: OAuth Review
# ---
#
# ![](https://g.twimg.com/dev/documentation/image/appauth_0.png)

# %% [markdown]
# ## What's Going On Here?

# %% [markdown]
# ## Our Application Keys
# ---
#
# Take note of the application keys you’ll use to connect to Twitter and mine tweets from the official Bernie Sanders and Donald Trump accounts.
#
# ![](https://snag.gy/H1djQK.jpg)

# %% [markdown]
# ## `TweetMiner` Class Structure
#
# ---
#
# The following code will get you up and running by providing connectivity to Twitter. The class has the ability to make requests and can eventually transform the JSON responses into DataFrames.
#
# This is a great example of using object-oriented Python to organize our code.
#
# > **Note:** `request_limit` is used in this class to limit the number of tweets that are pulled per instance request. Setting it to something lower until you've worked out the bugs in your request and captured the data you want is essential for avoiding rate limit blocks.
#
# ### Twitter API Key Set Up
#
# Fill the information below in with the keys for your account.
#
# - **consumer_key**: Find this on your application page under the Keys and Access Tokens tab.
# - **consumer_secret**: This is located right under **consumer_key** in the Keys and Access Tokens tab.
# - **access_token_key**: To get this, you'll need to click the button to generate tokens.
# - **access_token_secret**: This is available after you generate tokens.

# %%
import twitter, re, datetime, pandas as pd

# Your keys go here:
twitter_keys = {
    'consumer_key':        'DqFn7xHyZu7wq1GwRi41wEnYR',
    'consumer_secret':     'awmJHrGo5laMAM1gISw42ouHfE0Mhp2H7y5bDcpOFgxxnTjgh1',
    'access_token_key':    '2597493216-uFDmKb5SZbZY47Tv9nhIehAycs6xKFGXJj5pViZ',
    'access_token_secret': 'rCAZuf7pX8iwDIjybUE0yKOlNfD4TuPK07AVWCzQ1ENJt'
}

api = twitter.Api(
    consumer_key         =   twitter_keys['consumer_key'],
    consumer_secret      =   twitter_keys['consumer_secret'],
    access_token_key     =   twitter_keys['access_token_key'],
    access_token_secret  =   twitter_keys['access_token_secret']
)

# %%
class TweetMiner(object):

    result_limit    =   20    
    api             =   False
    data            =   []
    
    def __init__(self, keys_dict, api, result_limit = 20):
        
        self.api = api
        self.twitter_keys = keys_dict
        
        self.result_limit = result_limit
        

    def mine_user_tweets(self, user="dyerrington", mine_rewteets=False, max_pages=5):

        data           =  []
        last_tweet_id  =  False
        page           =  1
        
        while page <= max_pages:
            
            if last_tweet_id:
                statuses   =   self.api.GetUserTimeline(screen_name=user, count=self.result_limit, max_id=last_tweet_id - 1)        
            else:
                statuses   =   self.api.GetUserTimeline(screen_name=user, count=self.result_limit)
                
            for item in statuses:

                mined = {
                    'tweet_id':        item.id,
                    'handle':          item.user.name,
                    'retweet_count':   item.retweet_count,
                    'text':            item.text,
                    'mined_at':        datetime.datetime.now(),
                    'created_at':      item.created_at,
                }
                
                last_tweet_id = item.id
                data.append(mined)
                
            page += 1
            
        return data

# %% [markdown]
# ## Instantiate the Class
# ---
#
# Make sure you pass the keys dictionary and the API as arguments.
#
# **Check:** Call the object's `mine_user_tweets()` method, providing a user from whom to pull tweets.

# %%
tweet_dict = TweetMiner(twitter_keys, api).mine_user_tweets()

# %% [markdown]
# ### Convert the Tweet Outputs to a Pandas DataFrame
#
# > *Hint: This is as easy as passing it to the DataFrame constructor!*

# %%
df = pd.DataFrame(tweet_dict)
df
# Out:
#                         created_at            handle                mined_at  \
# 0   Sat Mar 25 05:31:15 +0000 2017  David Yerrington 2018-07-19 10:49:10.519
# 1   Wed May 18 05:47:02 +0000 2016  David Yerrington 2018-07-19 10:49:10.519
# 2   Mon Dec 14 20:44:06 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 3   Tue Sep 01 20:09:19 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 4   Tue Sep 01 18:44:54 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 5   Fri Aug 21 22:33:49 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 6   Fri Aug 21 22:29:42 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 7   Fri Aug 21 18:48:27 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 8   Thu Aug 20 23:24:47 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 9   Thu Aug 20 20:17:44 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 10  Sat Jul 11 19:11:18 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 11  Sat Jul 11 19:03:51 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 12  Fri Jun 12 20:04:33 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 13  Tue May 19 21:45:52 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 14  Thu May 14 21:41:35 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 15  Wed May 13 16:10:42 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 16  Thu Apr 30 15:45:12 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 17  Wed Apr 29 15:55:12 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 18  Tue Apr 28 15:45:16 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 19  Tue Apr 07 18:40:20 +0000 2015  David Yerrington 2018-07-19 10:49:10.519
# 20  Fri Apr 03 16:01:55 +0000 2015  David Yerrington 2018-07-19 10:49:10.826
# 21  Thu Apr 02 15:45:39 +0000 2015  David Yerrington 2018-07-19 10:49:10.826
# 22  Tue Mar 31 16:01:03 +0000 2015  David Yerrington 2018-07-19 10:49:10.826
# 23  Tue Mar 31 13:20:35 +0000 2015  David Yerrington 2018-07-19 10:49:10.826
# 24  Wed Mar 18 08:01:25 +0000 2015  David Yerrington 2018-07-19 10:49:10.826
# 25  Wed Mar 18 06:58:13 +0000 2015  David Yerrington 2018-07-19 10:49:10.826
# 26  Sat Mar 14 18:46:31 +0000 2015  David Yerrington 2018-07-19 10:49:10.826
# 27  Fri Mar 06 21:30:59 +0000 2015  David Yerrington 2018-07-19 10:49:10.826
# 28  Tue Mar 03 17:30:54 +0000 2015  David Yerrington 2018-07-19 10:49:10.826
# 29  Tue Mar 03 16:50:21 +0000 2015  David Yerrington 2018-07-19 10:49:10.826
# ..                             ...               ...                     ...
# 55  Fri Apr 26 18:49:29 +0000 2013  David Yerrington 2018-07-19 10:49:11.116
# 56  Fri Apr 26 05:11:27 +0000 2013  David Yerrington 2018-07-19 10:49:11.116
# 57  Fri Apr 26 00:10:45 +0000 2013  David Yerrington 2018-07-19 10:49:11.116
# 58  Fri Apr 26 00:09:43 +0000 2013  David Yerrington 2018-07-19 10:49:11.116
# 59  Fri Apr 26 00:09:18 +0000 2013  David Yerrington 2018-07-19 10:49:11.116
# 60  Thu Apr 25 22:52:18 +0000 2013  David Yerrington 2018-07-19 10:49:11.530
# 61  Thu Apr 25 10:10:27 +0000 2013  David Yerrington 2018-07-19 10:49:11.530
# 62  Thu Apr 25 05:14:29 +0000 2013  David Yerrington 2018-07-19 10:49:11.530
# 63  Thu Apr 25 05:12:17 +0000 2013  David Yerrington 2018-07-19 10:49:11.530
# 64  Thu Apr 25 05:07:32 +0000 2013  David Yerrington 2018-07-19 10:49:11.530
# 65  Sat Apr 13 04:42:36 +0000 2013  David Yerrington 2018-07-19 10:49:11.530
# 66  Wed Apr 10 05:02:24 +0000 2013  David Yerrington 2018-07-19 10:49:11.530
# 67  Tue Apr 09 03:11:18 +0000 2013  David Yerrington 2018-07-19 10:49:11.530
# 68  Tue Apr 09 03:08:46 +0000 2013  David Yerrington 2018-07-19 10:49:11.530
# 69  Fri Mar 29 21:06:21 +0000 2013  David Yerrington 2018-07-19 10:49:11.530
# 70  Thu Nov 29 04:32:36 +0000 2012  David Yerrington 2018-07-19 10:49:11.530
# 71  Thu Jul 19 21:40:09 +0000 2012  David Yerrington 2018-07-19 10:49:11.530
# 72  Fri Jul 13 22:30:09 +0000 2012  David Yerrington 2018-07-19 10:49:11.530
# 73  Fri Jul 13 18:53:12 +0000 2012  David Yerrington 2018-07-19 10:49:11.530
# 74  Fri Jul 13 18:51:25 +0000 2012  David Yerrington 2018-07-19 10:49:11.530
# 75  Fri Jul 13 03:05:07 +0000 2012  David Yerrington 2018-07-19 10:49:11.530
# 76  Fri Jul 13 02:27:01 +0000 2012  David Yerrington 2018-07-19 10:49:11.530
# 77  Tue Jun 19 19:53:18 +0000 2012  David Yerrington 2018-07-19 10:49:11.530
# 78  Tue Jun 19 19:30:35 +0000 2012  David Yerrington 2018-07-19 10:49:11.530
# 79  Tue Jun 19 04:16:01 +0000 2012  David Yerrington 2018-07-19 10:49:11.530
# 80  Mon Jun 18 17:36:52 +0000 2012  David Yerrington 2018-07-19 10:49:12.068
# 81  Sat Jun 16 11:20:17 +0000 2012  David Yerrington 2018-07-19 10:49:12.068
# 82  Mon Mar 05 18:25:48 +0000 2012  David Yerrington 2018-07-19 10:49:12.068
# 83  Thu Feb 16 17:04:37 +0000 2012  David Yerrington 2018-07-19 10:49:12.068
# 84  Mon Jan 30 02:14:06 +0000 2012  David Yerrington 2018-07-19 10:49:12.068
#
#     retweet_count                                               text  \
# 0               0  A new favorite: Deathforce - CD/MD: BlaqKemist...
# 1               0  A new favorite: Pieces by Ragle Gumm https://t...
# 2               0  Our project was a featured winner!  Thanks to ...
# 3               0  My @Quora answer to How I can upload a large d...
# 4               2  Initial commits for @livecodingtv chat-bots &a...
# 5               0  @itschriscates I think this book is awesome:  ...
# 6               0  @itschriscates yeah sure.  Point me at some da...
# 7               0  @itschriscates thanks Chris!  Next time we wil...
# 8              99  RT @DataScienceCtrl: Cheat Sheet: Data Visuali...
# 9               2  What is it like to interview as a data scienti...
# 10              0  @ChiedoJohn If this looks interesting, I'm ope...
# 11              0  @ChiedoJohn Glad to hear.  Want to work with i...
# 12              0  Probability dist explained simply with Naive B...
# 13              0  A new favorite: killer mike - 2 sides (bootleg...
# 14              0  @BerkeleyBowl Why do I keep buying bad avocado...
# 15              0  Topic modeling with LDA: MLlib meets GraphX ht...
# 16              0  First BigObject benchmark looks Amazing http:/...
# 17              0  Improper applications of Principal Component A...
# 18              1  Math of Ideas: A Word is Worth a Thousand Vect...
# 19              0  Zargoza 2012, #phototravel.  Even in the middl...
# 20              0  Sense.io Launches Data Science Platform to the...
# 21              0  I know it's a fad term, but when will it be de...
# 22              0  Cool mini-tutorial about using Markov chains t...
# 23              0  Barcelona Spain 2013 #phototravel.  This time ...
# 24              0  My @Quora answer to How do I make a program th...
# 25              0  My @Quora answer to I want to learn another pr...
# 26              0  My @Quora answer to Is deep learning pattern r...
# 27              0  @Webpass @satishd Here's mine this afternoon: ...
# 28              0  July 2010 Buenos Aires, #phototravel My first ...
# 29              0  Topic Models: Past, Present, Future http://t.c...
# ..            ...                                                ...
# 55              0  A new favorite: Steiners Story (hidden bonus t...
# 56              0  A new favorite: Big Down Under - world dub-ste...
# 57              1  A new favorite: Sleeping the morning (original...
# 58              0  A new favorite: Alborosie - Police Polizia (Fu...
# 59              0  A new favorite: Tears  &amp;  Bass  (Rogerio A...
# 60              0  A new favorite: BBQ Science #cabseries by @ale...
# 61              0  It's been several years since I've finished an...
# 62              0  A new favorite: PHOTO in Lounge - One by PHOTO...
# 63              0  A new favorite: Mr Scruff DJ Mix with MC Kwasi...
# 64              0  A new favorite: Something's Gone Awry by Jerem...
# 65              0  A new favorite: 501 - Feel For You by @wenever...
# 66              0  A new favorite: SPL - Show Me Love by @SPLSamu...
# 67              0  A new favorite: Dead Prez - Hip Hop by JeremyL...
# 68              0  A new favorite: Zedd vs Evan Duffy - Clarity (...
# 69              0  @jasonhinkle I watched \nFacebook Auth Part 2 ...
# 70              0  #Dubstep big gunner @whoszed comes through on ...
# 71              0  @GracenoteLabs Recommend artists like: Squarep...
# 72              0    @GracenoteLabs Recommend artists like: Ozomatli
# 73              0     @GracenoteLabs Recommend artists like: Santana
# 74              0  @GracenoteLabs Recommend artists like: Hank Wi...
# 75              0   @GracenoteLabs Recommend artists like: Snoop Dog
# 76              0               @GracenoteLabs Moodmash lastfm:xgote
# 77              0                         @Quiznatch How's it going?
# 78              0    Updating using OAuth authentication via Tweepy!
# 79              0  @snarshad I thought I saw you walking around t...
# 80              0  Had a fun time BCN -- thanks!  Great meeting e...
# 81              0  I presented Moodmash at Music Hack Day yesterd...
# 82              0  A new favorite: Kosheen-Spies by @kosheen1 htt...
# 83              0  Folks! I have 2 exclusive invites for Frank & ...
# 84              0                                  Account hacked :)
#
#               tweet_id
# 0   845508355632349184
# 1   732809702866849792
# 2   676502950856921088
# 3   638805859443806208
# 4   638784613293408257
# 5   634855956472426497
# 6   634854920382844928
# 7   634799241362145281
# 8   634506392674672640
# 9   634459320759939072
# 10  619947087652745216
# 11  619945213843275777
# 12  609451241211592704
# 13  600779430517153792
# 14  598966413894778880
# 15  598520754435727360
# 16  593803296827117568
# 17  593443425376149505
# 18  593078535180390402
# 19  585512447991226368
# 20  584023029363175424
# 21  583656548162994179
# 22  582935649394823168
# 23  582895265323040768
# 24  578103900814737408
# 25  578087995976196096
# 26  576816695785992192
# 27  573958980797665281
# 28  572811398499192832
# 29  572801192335675393
# ..                 ...
# 55  327856976426057728
# 56  327651113379708929
# 57  327575440724221952
# 58  327575179788169216
# 59  327575076444725248
# 60  327555697065725953
# 61  327363971634044928
# 62  327289490597109760
# 63  327288933920681984
# 64  327287739089305600
# 65  322932810736361473
# 66  321850629742018560
# 67  321460281089875969
# 68  321459645887705089
# 69  317744559369101312
# 70  274007932407005184
# 71  226068938100969473
# 72  223907192754020352
# 73  223852595251388419
# 74  223852146813177856
# 75  223614004495532035
# 76  223604416668897280
# 77  215170410378047488
# 78  215164694053396482
# 79  214934537279520768
# 80  214773690766864386
# 81  213954143495262208
# 82  176735276696219648
# 83  170191867605037056
# 84  163807168011841537
#
# [85 rows x 6 columns]

# %% [markdown]
# ##  Create the Training Data
#
# ---
#
# Let's get our mined data from the Twitter API.
#
# - Mine Trump tweets.
# - Create a tweet DataFrame.
# - Mine Sanders tweets.
# - Append the results to our DataFrame.

# %%
tweet_dict = TweetMiner(twitter_keys, api).mine_user_tweets(user='realDonaldTrump')

# %%
df = pd.DataFrame(tweet_dict)
df
# Out:
#                         created_at           handle                mined_at  \
# 0   Thu Jul 19 01:35:33 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 1   Wed Jul 18 21:34:12 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 2   Wed Jul 18 21:30:19 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 3   Wed Jul 18 21:29:06 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 4   Wed Jul 18 19:25:30 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 5   Wed Jul 18 17:12:53 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 6   Wed Jul 18 11:33:34 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 7   Wed Jul 18 11:27:59 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 8   Wed Jul 18 11:03:05 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 9   Wed Jul 18 10:44:18 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 10  Wed Jul 18 10:16:50 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 11  Wed Jul 18 10:08:36 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 12  Wed Jul 18 09:53:41 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 13  Wed Jul 18 04:10:19 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 14  Wed Jul 18 00:27:37 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 15  Wed Jul 18 00:21:54 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 16  Tue Jul 17 14:39:08 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 17  Tue Jul 17 14:33:47 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 18  Tue Jul 17 14:22:28 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 19  Tue Jul 17 13:53:39 +0000 2018  Donald J. Trump 2018-07-19 10:50:15.682
# 20  Mon Jul 16 22:53:47 +0000 2018  Donald J. Trump 2018-07-19 10:50:16.245
# 21  Mon Jul 16 20:34:07 +0000 2018  Donald J. Trump 2018-07-19 10:50:16.245
# 22  Mon Jul 16 20:29:54 +0000 2018  Donald J. Trump 2018-07-19 10:50:16.245
# 23  Mon Jul 16 19:40:23 +0000 2018  Donald J. Trump 2018-07-19 10:50:16.245
# 24  Mon Jul 16 16:51:20 +0000 2018  Donald J. Trump 2018-07-19 10:50:16.245
# 25  Mon Jul 16 16:11:26 +0000 2018  Donald J. Trump 2018-07-19 10:50:16.245
# 26  Mon Jul 16 08:56:58 +0000 2018  Donald J. Trump 2018-07-19 10:50:16.245
# 27  Mon Jul 16 06:05:29 +0000 2018  Donald J. Trump 2018-07-19 10:50:16.245
# 28  Mon Jul 16 05:37:05 +0000 2018  Donald J. Trump 2018-07-19 10:50:16.245
# 29  Mon Jul 16 05:23:50 +0000 2018  Donald J. Trump 2018-07-19 10:50:16.245
# ..                             ...              ...                     ...
# 70  Wed Jul 11 23:33:33 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.177
# 71  Wed Jul 11 22:47:16 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.177
# 72  Wed Jul 11 21:53:26 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.177
# 73  Wed Jul 11 21:11:54 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.177
# 74  Wed Jul 11 21:11:36 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.177
# 75  Wed Jul 11 21:11:20 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.177
# 76  Wed Jul 11 21:10:46 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.177
# 77  Wed Jul 11 21:10:31 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.177
# 78  Wed Jul 11 21:10:24 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.177
# 79  Wed Jul 11 21:10:11 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.177
# 80  Wed Jul 11 21:09:01 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 81  Wed Jul 11 17:07:27 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 82  Wed Jul 11 16:41:12 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 83  Wed Jul 11 12:40:32 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 84  Wed Jul 11 12:40:31 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 85  Wed Jul 11 08:04:45 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 86  Tue Jul 10 22:37:28 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 87  Tue Jul 10 18:52:21 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 88  Tue Jul 10 18:42:21 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 89  Tue Jul 10 17:01:30 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 90  Tue Jul 10 14:49:17 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 91  Tue Jul 10 14:40:12 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 92  Tue Jul 10 12:39:18 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 93  Tue Jul 10 11:38:10 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 94  Tue Jul 10 10:59:30 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 95  Tue Jul 10 10:44:29 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 96  Tue Jul 10 10:42:43 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 97  Tue Jul 10 09:35:05 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 98  Tue Jul 10 09:07:47 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
# 99  Tue Jul 10 09:03:04 +0000 2018  Donald J. Trump 2018-07-19 10:50:17.577
#
#     retweet_count                                               text  \
# 0           10823  A total disgrace that Turkey will not release ...
# 1            6989  RT @SecAzar: .@POTUS has made clear that it’s ...
# 2           17989  The two biggest opponents of ICE in America to...
# 3           10753  Thank you to Congressman Kevin Yoder! He secur...
# 4           17833  Brian Kemp is running for Governor of the grea...
# 5           12183  RT @SecretService: In Remembrance: Special Age...
# 6           19694  3.4 million jobs created since our great Elect...
# 7           29106  Some people HATE the fact that I got along wel...
# 8           14008  “A lot of Democrats wished they voted for the ...
# 9           11219  Congratulations to Martha Roby of The Great St...
# 10          14478  ....Russia has agreed to help with North Korea...
# 11          14366  While the NATO meeting in Brussels was an ackn...
# 12          19103  So many people at the higher ends of intellige...
# 13          20801  “Prosperity is returning. Donald Trump is doin...
# 14          28809  The Democrats want to abolish ICE, which will ...
# 15          22220  The meeting between President Putin and myself...
# 16          23465  The economy of the United States is stronger t...
# 17          20539  Thank you @RandPaul. “The President has gone t...
# 18          23317  While I had a great meeting with NATO, raising...
# 19          22011  I had a great meeting with NATO. They have pai...
# 20          14893  Will be interviewed on @seanhannity tonight at...
# 21          21135  A productive dialogue is not only good for the...
# 22          34543  I would rather take a political risk in pursui...
# 23          29925  As I said today and many times before, “I have...
# 24          16821  Thank you Helsinki, Finland! https://t.co/rh4N...
# 25          13217  Joint Press Conference from Helsinki, Finland:...
# 26          10609  It was an honor to join you this morning. Than...
# 27          23279  Our relationship with Russia has NEVER been wo...
# 28          34682  President Obama thought that Crooked Hillary w...
# 29          21600  Received many calls from leaders of NATO count...
# ..            ...                                                ...
# 70          19097  Billions of additional dollars are being spent...
# 71          21593  How can the Rigged Witch Hunt proceed when it ...
# 72          24102  Ex-FBI LAYER Lisa Page today defied a House of...
# 73          29526  RT @realDonaldTrump: What good is NATO if Germ...
# 74           5125  RT @Scavino45: President @realDonaldTrump and ...
# 75           5129  RT @Scavino45: President @realDonaldTrump meet...
# 76          13686  RT @realDonaldTrump: ...things up, better than...
# 77          17376  RT @realDonaldTrump: I am in Brussels, but alw...
# 78          22383  RT @realDonaldTrump: Democrats in Congress mus...
# 79           6926  RT @Scavino45: President Donald J. Trump and F...
# 80          18462  If the Democrats want to win Supreme Court and...
# 81          29526  What good is NATO if Germany is paying Russia ...
# 82          22383  Democrats in Congress must no longer Obstruct ...
# 83          13686  ...things up, better than ever before, but it ...
# 84          17376  I am in Brussels, but always thinking about ou...
# 85          19389  Bilateral Breakfast with NATO Secretary Genera...
# 86          25609  Just talked with Pfizer CEO and @SecAzar on ou...
# 87          24457  The European Union makes it impossible for our...
# 88          21711  A recent Emerson College ePoll said that most ...
# 89          18485  Many countries in NATO, which we are expected ...
# 90           9520  Informing the Republican Senators of my nomina...
# 91          25347  I am on Air Force One flying to NATO and hear ...
# 92          40353  On behalf of the United States, congratulation...
# 93         108825  RT @realDonaldTrump: They just didn't get it, ...
# 94          25815  Thank you to all of my great supporters, reall...
# 95           6435  RT @ShennaFoxxx: @realDonaldTrump #TrumpUKVisi...
# 96          14003  NATO countries must pay MORE, the United State...
# 97          15618  Getting ready to leave for Europe. First meeti...
# 98          10548  RT @KatrinaPierson: The stupidity of the left ...
# 99          38633  RT @realDonaldTrump: Iranian Harassment of U.S...
#
#                tweet_id
# 0   1019757603570806785
# 1   1019696867481964544
# 2   1019695889626083331
# 3   1019695583853010944
# 4   1019664477162278918
# 5   1019631102535897088
# 6   1019545713435467776
# 7   1019544304853966853
# 8   1019538038651871233
# 9   1019533312052858880
# 10  1019526399542091776
# 11  1019524328927453184
# 12  1019520574371123200
# 13  1019434161889796097
# 14  1019378119671730176
# 15  1019376680572456960
# 16  1019230023897833479
# 17  1019228676460773377
# 18  1019225830298456066
# 19  1019218575691837443
# 20  1018992115810910208
# 21  1018956970143858688
# 22  1018955906690584576
# 23  1018943446583668736
# 24  1018900904735531014
# 25  1018890862653157381
# 26  1018781525309943808
# 27  1018738368753078273
# 28  1018731223890481153
# 29  1018727890345693184
# ..                  ...
# 70  1017190186269184001
# 71  1017178539706212353
# 72  1017164990099415041
# 73  1017154540284542981
# 74  1017154462727790597
# 75  1017154397665726464
# 76  1017154254694506496
# 77  1017154189569527809
# 78  1017154161270550530
# 79  1017154104735432711
# 80  1017153813625626624
# 81  1017093020783710209
# 82  1017086416176730112
# 83  1017025848409550848
# 84  1017025845905494016
# 85  1016956445307400193
# 86  1016813686051233800
# 87  1016757033071079424
# 88  1016754517415624704
# 89  1016729137409486853
# 90  1016695860267134976
# 91  1016693575344504832
# 92  1016663151935291393
# 93  1016647764434931713
# 94  1016638035281219584
# 95  1016634257857568769
# 96  1016633811378073602
# 97  1016616792926703616
# 98  1016609920031117312
# 99  1016608735727439872
#
# [100 rows x 6 columns]

# %% [markdown]
# ## Are There Any Interesting N-Grams Going on With Trump?
# ---
#
# Set up a vectorizer from scikit-learn and fit the text of Trump's tweets with an n-gram range of two to four. Identify the most common n-grams.
#
# > **Note:** It's up to you whether or not you want to remove stop words. How does keeping or removing stop words affect the results?

# %%
# A:

# %% [markdown]
# ### Look at the N-Grams for Bernie Sanders

# %%
# A:

# %% [markdown]
# ## Processing the Tweets and Building a Model
#
# ---
#
# To perform classification, we'll need to convert the tweets into a set of features.
#
# **You will need to:**
# - Vectorize and input text data.
# - Initialize a model (try logistic regression).
# - Train, predict, and cross-validate.
# - Evaluate the performance of the model.
#
# > **Bonus:** You may have noticed that there are website links in the tweets. What additional preprocessing steps can you take before building the model?

# %%
# A:

# %% [markdown]
# ## Check the Predicted Probability for a Random Sanders and Trump Tweet
# ---
#
# A couple of tweets from both Sanders and Trump are provided below.
#
# Estimate the predicted probability of Trump being the author for the two tweets.

# %%
# Prep our source as TF-IDF vectors.
source_test = [
    "Demanding that the wealthy and the powerful start paying their fair share of taxes that's exactly what the American people want.",
    "Crooked Hillary is spending tremendous amounts of Wall Street money on false ads against me. She is a very dishonest person!"
]

############
# Note: Do not re-initialize the TF-IDF vectorizer or the feature space will be overwritten and
# your transform will not match the number of features on which you trained your model.
#
# You only need to transform because you fit previously.
#
####

# %% [markdown]
# ## Independent Practice Questions
#
# ---

# %% [markdown]
# ### 1) Pull tweets for some new users.
#
# Experiment with using more data. The API will not like it if you blow through its limits, so be careful. Try to grab only what you need one time, then work on the copy of the objects that are returned.
#
# > Read the documentation about rate limits and see if you can get enough without hitting the limit. Are there any options available in the API to avoid such a problem?
#
# **Pull tweets for more than two different users of your choice.**

# %%
# A:

# %% [markdown]
# ### 2) Build a multi-class classification model to distinguish between the users.
#
# Try a different model than what we used before.

# %%
# A:

# %% [markdown]
# ### 3) Create a confusion matrix and a classification report.

# %%
# A:

# %% [markdown]
# ### 4) What are the most and least "distinctive" tweets for each user?
#
# To find this, identify the tweet that has the highest (correct) predicted probability of being that user's tweet for each user.

# %%
# A:

# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Introduction to `pandas` Grouping
#
# _Authors: Kiefer Katovich (SF), Dave Yerrington (SF), Mario Carrillo (SF)_
#
# ---

# %% [markdown]
# ### Learning Objectives
# *After this lesson, you will be able to:*
# - Identify the situations in which **grouping** is useful.
# - Explain and use the **`.groupby()`** function in `pandas`.
# - Demonstrate aggregation and plotting methods by groups in `pandas`.

# %% [markdown]
# ### Lesson Guide
#
# - [Overview of Multi-Dimensional Data Analysis](#overview)
# - [Analyzing Data by Group: Examples](#grouping_examples)
# - [Exploring the Titanic Data Set with Grouping](#load_titanic)
# - [Introducing `pandas` `.groupby()` Function](#groupby)
# - [Grouping by Multiple Variables](#groupby_multiple)
# - [Applying Basic Functions to Groups](#basic_functions)
# - [Removing the Hierarchical Index](#removing_hierarchical)
# - [Applying Custom Functions with `.apply()`](#custom_functions)
# - [Plotting Basic Histograms with Groups](#basic_plotting)
# - [Grouped Histograms with `pandas`](#grouped_hists)
# - [Independent Practice](#independent_practice)

# %% [markdown]
# <a id='overview'></a>
#
# ### Overview of Multi-Dimensional Data Analysis
#
# ---
#
# Multi-dimensional data analysis allows you to:
#
# - Describe segments of your data based on unique values.
# - Understand characteristics of your data.
#    - Calculate summary statistics across subsets.
#    - Discover patterns that exist in some subsets but not others.
# - Find duplicate values or redundant data.
# - Apply aggregate functions to subsets.

# %% [markdown]
# <a id='grouping_examples'></a>
#
# ### Analyzing Data by Group: Examples
#
# ---
#
# Scenarios include determining the:
#
#  - Sum of crimes by time of day in San Francisco (morning, afternoon, night).
#  - Count number of people with the same last name.
#  - Median number of multi-unit buildings in a region.
#  - Popularity of movie genres by region.
#  - Customer segments based on age, buying habits, interests, and behavior.
#
#  You can also apply the "GROUP BY" clause in a database query using SQL.

# %% [markdown]
# #### Subset Aggregation:
#
# This chart stratifies a single variable, "industry," **counting** job openings within a specific category.
#
# ![](http://www.rasmussen.edu/images/blogs/1360270834-402_Graphs_JobOpeningsByIndustry.jpg)

# %% [markdown]
# #### Hierarchical Aggregation
#
# This chart aggregates first by a top-level group, "industry," and then by a secondary group, "date," within each industry.
#
# ![](http://junkcharts.typepad.com/.a/6a00d8341e992c53ef0192acc65090970d-pi)

# %% [markdown]
# <a id='load_titanic'></a>
#
# ### Exploring the Titanic Data Set with Grouping
#
# ---
#
# To explore the power of grouping with `pandas`, we will be using [the famous Titanic data set](https://www.kaggle.com/c/titanic), which can be downloaded from Kaggle. Here's the competition description:
#
# >The sinking of the RMS Titanic is one of the most infamous shipwrecks in history. On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1,502 out of 2,224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# >One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper class.
#
# Although we will not be modeling survival rates in this lesson, there are interesting patterns to be found just by exploring descriptive statistics in cross-sections of the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# **Load the data into `pandas`.**

# %%
path_to_file = './datasets/titanic_clean.csv'
df = pd.read_csv(path_to_file)
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch     Fare Embarked
# 0      0   7.2500        S
# 1      0  71.2833        C
# 2      0   7.9250        S

# %% [markdown]
# The data contains a variety of information about the passengers present at the sinking of the Titanic.
#
# **Describe the data in the columns with summary statistics.**

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   712.000000  712.000000  712.000000  712.000000  712.000000
# mean    448.589888    0.404494    2.240169   29.642093    0.514045
# std     258.683191    0.491139    0.836854   14.492933    0.930692
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     222.750000    0.000000    1.000000   20.000000    0.000000
# 50%     445.000000    0.000000    2.000000   28.000000    0.000000
# 75%     677.250000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  712.000000  712.000000
# mean     0.432584   34.567251
# std      0.854181   52.938648
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.645850
# 75%      1.000000   33.000000
# max      6.000000  512.329200

# %% [markdown]
# <a id='groupby'></a>
#
# ### Introducing `pandas`' `.groupby()` Function
#
# ---
#
# The built-in `.groupby()` function for DataFrames is one of the most useful tools in `pandas`. As the name implies, `.groupby()` will group your data set by one or more user-specified column names.
#
# **Using `.groupby()`, create a grouped DataFrame in which the Titanic data set is grouped by "Pclass."**

# %%
df.groupby('Pclass')

# %% [markdown]
# **Print out the type of the grouped DataFrame.**

# %%
type(df.groupby('Pclass'))
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %% [markdown]
# Instead of a `DataFrame` object, we now have a `DataFrameGroupBy` object. This operates somewhat differently than the DataFrames we're used to, as we'll soon see.
#
# **Try pulling out the first group from the grouped DataFrame with index 0.**

# %%
pclassgrp = df.groupby('Pclass')
pclassgrp[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-a6fa0be035e8> in <module>()
#       1 pclassgrp = df.groupby('Pclass')
# ----> 2 pclassgrp[0]
#
# C:\Users\Samson\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\base.pyc in __getitem__(self, key)
#     257         else:
#     258             if key not in self.obj:
# --> 259                 raise KeyError("Column not found: {key}".format(key=key))
#     260             return self._gotitem(key, ndim=1)
#     261
#
# KeyError: 'Column not found: 0'

# %% [markdown]
# Grouped DataFrames operate differently than Python lists. You can't pull out different groups with indexers. Despite this, grouped DataFrame objects **are** iterable! You can step through them using a for loop, for example.
#
# In our grouped DataFrame, each element will be a tuple containing the "Pclass" group as its first element and the subset of the original Titanic DataFrame for that "Pclass" as its second element.
#
# **Write a for loop to iterate through the grouped DataFrame, printing out the "PClass" and the header of the subset each time.**

# %%
len(pclassgrp)
for i in pclassgrp:
    print i
# Out:
# (1L,      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 5              7         0       1
# 10            12         1       1
# 20            24         1       1
# 23            28         0       1
# 24            31         0       1
# 26            35         0       1
# 27            36         0       1
# 38            53         1       1
# 40            55         0       1
# 46            63         0       1
# 62            84         0       1
# 66            89         1       1
# 70            93         0       1
# 73            97         0       1
# 74            98         1       1
# 78           103         0       1
# 84           111         0       1
# 92           119         0       1
# 97           125         0       1
# 107          137         1       1
# 108          138         0       1
# 110          140         0       1
# 121          152         1       1
# 124          156         0       1
# 135          171         0       1
# 139          175         0       1
# 141          178         0       1
# 147          188         1       1
# ..           ...       ...     ...
# 586          738         1       1
# 587          742         0       1
# 588          743         1       1
# 591          746         0       1
# 594          749         0       1
# 605          760         1       1
# 608          764         1       1
# 610          766         1       1
# 619          780         1       1
# 621          782         1       1
# 622          783         0       1
# 628          790         0       1
# 632          797         1       1
# 638          803         1       1
# 642          807         0       1
# 645          810         1       1
# 655          821         1       1
# 657          823         0       1
# 665          836         1       1
# 670          843         1       1
# 679          854         1       1
# 682          857         1       1
# 683          858         1       1
# 687          863         1       1
# 691          868         0       1
# 694          872         1       1
# 695          873         0       1
# 701          880         1       1
# 709          888         1       1
# 710          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                            Bonnell, Miss. Elizabeth  female  58.0      0
# 20                        Sloper, Mr. William Thompson    male  28.0      0
# 23                      Fortune, Mr. Charles Alexander    male  19.0      3
# 24                            Uruchurtu, Don. Manuel E    male  40.0      0
# 26                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 27                      Holverson, Mr. Alexander Oskar    male  42.0      1
# 38            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 40                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 46                         Harris, Mr. Henry Birkhardt    male  45.0      1
# 62                             Carrau, Mr. Francisco M    male  28.0      0
# 66                          Fortune, Miss. Mabel Helen  female  23.0      3
# 70                         Chaffee, Mr. Herbert Fuller    male  46.0      1
# 73                           Goldschmidt, Mr. George B    male  71.0      0
# 74                     Greenfield, Mr. William Bertram    male  23.0      0
# 78                           White, Mr. Richard Frasar    male  21.0      0
# 84                      Porter, Mr. Walter Chamberlain    male  47.0      0
# 92                            Baxter, Mr. Quigg Edmond    male  24.0      0
# 97                         White, Mr. Percival Wayland    male  54.0      0
# 107                       Newsom, Miss. Helen Monypeny  female  19.0      0
# 108                        Futrelle, Mr. Jacques Heath    male  37.0      1
# 110                                 Giglio, Mr. Victor    male  24.0      0
# 121                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 124                        Williams, Mr. Charles Duane    male  51.0      0
# 135                          Van der hoef, Mr. Wyckoff    male  61.0      0
# 139                            Smith, Mr. James Clinch    male  56.0      0
# 141                         Isham, Miss. Ann Elizabeth  female  50.0      0
# 147      Romaine, Mr. Charles Hallace ("Mr C Rolmane")    male  45.0      0
# ..                                                 ...     ...   ...    ...
# 586                             Lesurer, Mr. Gustave J    male  35.0      0
# 587                      Cavendish, Mr. Tyrell William    male  36.0      1
# 588              Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
# 591                       Crosby, Capt. Edward Gifford    male  70.0      1
# 594                          Marvin, Mr. Daniel Warner    male  19.0      1
# 605  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 608          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0      1
# 610               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1
# 619  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 621          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 622                             Long, Mr. Milton Clyde    male  29.0      0
# 628                           Guggenheim, Mr. Benjamin    male  46.0      0
# 632                        Leader, Dr. Alice (Farnham)  female  49.0      0
# 638                Carter, Master. William Thornton II    male  11.0      1
# 642                             Andrews, Mr. Thomas Jr    male  39.0      0
# 645     Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.0      1
# 655  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 657                    Reuchlin, Jonkheer. John George    male  38.0      0
# 665                        Compton, Miss. Sara Rebecca  female  39.0      1
# 670                            Serepeca, Miss. Augusta  female  30.0      0
# 679                          Lines, Miss. Mary Conover  female  16.0      0
# 682         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 683                             Daly, Mr. Peter Denis     male  51.0      0
# 687  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 691               Roebling, Mr. Washington Augustus II    male  31.0      0
# 694   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 695                           Carlsson, Mr. Frans Olof    male  33.0      0
# 701      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 709                       Graham, Miss. Margaret Edith  female  19.0      0
# 710                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch      Fare Embarked
# 1        0   71.2833        C
# 3        0   53.1000        S
# 5        0   51.8625        S
# 10       0   26.5500        S
# 20       0   35.5000        S
# 23       2  263.0000        S
# 24       0   27.7208        C
# 26       0   82.1708        C
# 27       0   52.0000        S
# 38       0   76.7292        C
# 40       1   61.9792        C
# 46       0   83.4750        S
# 62       0   47.1000        S
# 66       2  263.0000        S
# 70       0   61.1750        S
# 73       0   34.6542        C
# 74       1   63.3583        C
# 78       1   77.2875        S
# 84       0   52.0000        S
# 92       1  247.5208        C
# 97       1   77.2875        S
# 107      2   26.2833        S
# 108      0   53.1000        S
# 110      0   79.2000        C
# 121      0   66.6000        S
# 124      1   61.3792        C
# 135      0   33.5000        S
# 139      0   30.6958        C
# 141      0   28.7125        C
# 147      0   26.5500        S
# ..     ...       ...      ...
# 586      0  512.3292        C
# 587      0   78.8500        S
# 588      2  262.3750        C
# 591      1   71.0000        S
# 594      0   53.1000        S
# 605      0   86.5000        S
# 608      2  120.0000        S
# 610      0   77.9583        S
# 619      1  211.3375        S
# 621      0   57.0000        S
# 622      0   30.0000        S
# 628      0   79.2000        C
# 632      0   25.9292        S
# 638      2  120.0000        S
# 642      0    0.0000        S
# 645      0   53.1000        S
# 655      1   93.5000        S
# 657      0    0.0000        S
# 665      1   83.1583        C
# 670      0   31.0000        C
# 679      1   39.4000        S
# 682      1  164.8667        S
# 683      0   26.5500        S
# 687      0   25.9292        S
# 691      0   50.4958        S
# 694      1   52.5542        S
# 695      0    5.0000        S
# 701      1   83.1583        C
# 709      0   30.0000        S
# 710      0   30.0000        C
#
# [184 rows x 10 columns])
# (2L,      PassengerId  Survived  Pclass  \
# 8             10         1       2
# 14            16         1       2
# 17            21         0       2
# 18            22         1       2
# 25            34         0       2
# 32            42         0       2
# 33            44         1       2
# 39            54         1       2
# 41            57         1       2
# 43            59         1       2
# 48            67         1       2
# 52            71         0       2
# 54            73         0       2
# 58            79         1       2
# 63            85         1       2
# 75            99         1       2
# 76           100         0       2
# 91           118         0       2
# 94           121         0       2
# 95           123         0       2
# 96           124         1       2
# 104          134         1       2
# 105          135         0       2
# 106          136         0       2
# 114          145         0       2
# 115          146         0       2
# 118          149         0       2
# 119          150         0       2
# 120          151         0       2
# 128          162         1       2
# ..           ...       ...     ...
# 578          729         0       2
# 582          734         0       2
# 583          735         0       2
# 593          748         1       2
# 596          751         1       2
# 600          755         1       2
# 601          756         1       2
# 603          758         0       2
# 615          773         0       2
# 616          775         1       2
# 629          792         0       2
# 631          796         0       2
# 636          801         0       2
# 637          802         1       2
# 644          809         0       2
# 648          813         0       2
# 652          818         0       2
# 660          828         1       2
# 662          832         1       2
# 669          842         0       2
# 675          849         0       2
# 680          855         0       2
# 686          862         0       2
# 688          865         0       2
# 689          866         1       2
# 690          867         1       2
# 697          875         1       2
# 702          881         1       2
# 705          884         0       2
# 708          887         0       2
#
#                                                   Name     Sex    Age  SibSp  \
# 8                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.00      1
# 14                    Hewlett, Mrs. (Mary D Kingcome)   female  55.00      0
# 17                                Fynney, Mr. Joseph J    male  35.00      0
# 18                               Beesley, Mr. Lawrence    male  34.00      0
# 25                               Wheadon, Mr. Edward H    male  66.00      0
# 32   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.00      1
# 33            Laroche, Miss. Simonne Marie Anne Andree  female   3.00      1
# 39   Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.00      1
# 41                                   Rugg, Miss. Emily  female  21.00      0
# 43                        West, Miss. Constance Mirium  female   5.00      1
# 48                        Nye, Mrs. (Elizabeth Ramell)  female  29.00      0
# 52                          Jenkin, Mr. Stephen Curnow    male  32.00      0
# 54                                Hood, Mr. Ambrose Jr    male  21.00      0
# 58                       Caldwell, Master. Alden Gates    male   0.83      0
# 63                                 Ilett, Miss. Bertha  female  17.00      0
# 75                Doling, Mrs. John T (Ada Julia Bone)  female  34.00      0
# 76                                   Kantor, Mr. Sinai    male  34.00      1
# 91                     Turpin, Mr. William John Robert    male  29.00      1
# 94                         Hickman, Mr. Stanley George    male  21.00      2
# 95                                Nasser, Mr. Nicholas    male  32.50      1
# 96                                 Webber, Miss. Susan  female  32.50      0
# 104      Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.00      1
# 105                     Sobey, Mr. Samuel James Hayden    male  25.00      0
# 106                                 Richard, Mr. Emile    male  23.00      0
# 114                         Andrew, Mr. Edgardo Samuel    male  18.00      0
# 115                       Nicholls, Mr. Joseph Charles    male  19.00      1
# 118           Navratil, Mr. Michel ("Louis M Hoffman")    male  36.50      0
# 119                  Byles, Rev. Thomas Roussel Davids    male  42.00      0
# 120                         Bateman, Rev. Robert James    male  51.00      0
# 128  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  female  40.00      0
# ..                                                 ...     ...    ...    ...
# 578                    Bryhl, Mr. Kurt Arnold Gottfrid    male  25.00      1
# 582                         Berriman, Mr. William John    male  23.00      0
# 583                       Troupiansky, Mr. Moses Aaron    male  23.00      0
# 593                              Sinkkonen, Miss. Anna  female  30.00      0
# 596                                  Wells, Miss. Joan  female   4.00      1
# 600                   Herman, Mrs. Samuel (Jane Laver)  female  48.00      1
# 601                          Hamalainen, Master. Viljo    male   0.67      1
# 603                           Bailey, Mr. Percy Andrew    male  18.00      0
# 615                                  Mack, Mrs. (Mary)  female  57.00      0
# 616              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.00      1
# 629                                Gaskell, Mr. Alfred    male  16.00      0
# 631                                 Otter, Mr. Richard    male  39.00      0
# 636                               Ponesell, Mr. Martin    male  34.00      0
# 637        Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.00      1
# 644                                  Meyer, Mr. August    male  39.00      0
# 648                          Slemen, Mr. Richard James    male  35.00      0
# 652                                 Mallet, Mr. Albert    male  31.00      1
# 660                              Mallet, Master. Andre    male   1.00      0
# 662                    Richards, Master. George Sibley    male   0.83      1
# 669                           Mudd, Mr. Thomas Charles    male  16.00      0
# 675                                  Harper, Rev. John    male  28.00      0
# 680      Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.00      1
# 686                        Giles, Mr. Frederick Edward    male  21.00      1
# 688                             Gill, Mr. John William    male  24.00      0
# 689                           Bystrom, Mrs. (Karolina)  female  42.00      0
# 690                       Duran y More, Miss. Asuncion  female  27.00      1
# 697              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.00      1
# 702       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.00      0
# 705                      Banfield, Mr. Frederick James    male  28.00      0
# 708                              Montvila, Rev. Juozas    male  27.00      0
#
#      Parch     Fare Embarked
# 8        0  30.0708        C
# 14       0  16.0000        S
# 17       0  26.0000        S
# 18       0  13.0000        S
# 25       0  10.5000        S
# 32       0  21.0000        S
# 33       2  41.5792        C
# 39       0  26.0000        S
# 41       0  10.5000        S
# 43       2  27.7500        S
# 48       0  10.5000        S
# 52       0  10.5000        S
# 54       0  73.5000        S
# 58       2  29.0000        S
# 63       0  10.5000        S
# 75       1  23.0000        S
# 76       0  26.0000        S
# 91       0  21.0000        S
# 94       0  73.5000        S
# 95       0  30.0708        C
# 96       0  13.0000        S
# 104      0  26.0000        S
# 105      0  13.0000        S
# 106      0  15.0458        C
# 114      0  11.5000        S
# 115      1  36.7500        S
# 118      2  26.0000        S
# 119      0  13.0000        S
# 120      0  12.5250        S
# 128      0  15.7500        S
# ..     ...      ...      ...
# 578      0  26.0000        S
# 582      0  13.0000        S
# 583      0  13.0000        S
# 593      0  13.0000        S
# 596      1  23.0000        S
# 600      2  65.0000        S
# 601      1  14.5000        S
# 603      0  11.5000        S
# 615      0  10.5000        S
# 616      3  23.0000        S
# 629      0  26.0000        S
# 631      0  13.0000        S
# 636      0  13.0000        S
# 637      1  26.2500        S
# 644      0  13.0000        S
# 648      0  10.5000        S
# 652      1  37.0042        C
# 660      2  37.0042        C
# 662      1  18.7500        S
# 669      0  10.5000        S
# 675      1  33.0000        S
# 680      0  26.0000        S
# 686      0  11.5000        S
# 688      0  13.0000        S
# 689      0  13.0000        S
# 690      0  13.8583        C
# 697      0  24.0000        C
# 702      1  26.0000        S
# 705      0  10.5000        S
# 708      0  13.0000        S
#
# [173 rows x 10 columns])
# (3L,      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              8         0       3
# 7              9         1       3
# 9             11         1       3
# 11            13         0       3
# 12            14         0       3
# 13            15         0       3
# 15            17         0       3
# 16            19         0       3
# 19            23         1       3
# 21            25         0       3
# 22            26         1       3
# 28            38         0       3
# 29            39         0       3
# 30            40         1       3
# 31            41         0       3
# 34            45         1       3
# 35            50         0       3
# 36            51         0       3
# 37            52         0       3
# 42            58         0       3
# 44            60         0       3
# 45            61         0       3
# 47            64         0       3
# 49            68         0       3
# 50            69         1       3
# 51            70         0       3
# 53            72         0       3
# ..           ...       ...     ...
# 656          822         1       3
# 658          824         1       3
# 659          825         0       3
# 661          831         1       3
# 663          834         0       3
# 664          835         0       3
# 666          837         0       3
# 667          839         1       3
# 668          841         0       3
# 671          844         0       3
# 672          845         0       3
# 673          846         0       3
# 674          848         0       3
# 676          851         0       3
# 677          852         0       3
# 678          853         0       3
# 681          856         1       3
# 684          859         1       3
# 685          861         0       3
# 692          870         1       3
# 693          871         0       3
# 696          874         0       3
# 698          876         1       3
# 699          877         0       3
# 700          878         0       3
# 703          882         0       3
# 704          883         0       3
# 706          885         0       3
# 707          886         0       3
# 711          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                       Palsson, Master. Gosta Leonard    male   2.0      3
# 7    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                      Saundercock, Mr. William Henry    male  20.0      0
# 12                         Andersson, Mr. Anders Johan    male  39.0      1
# 13                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                                Rice, Master. Eugene    male   2.0      4
# 16   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 21                       Palsson, Miss. Torborg Danira  female   8.0      3
# 22   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 28                            Cann, Mr. Ernest Charles    male  21.0      0
# 29                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 30                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# 31      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 34                       Devaney, Miss. Margaret Delia  female  19.0      0
# 35       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 36                          Panula, Master. Juha Niilo    male   7.0      4
# 37                        Nosworthy, Mr. Richard Cater    male  21.0      0
# 42                                 Novel, Mr. Mansouer    male  28.5      0
# 44                  Goodwin, Master. William Frederick    male  11.0      5
# 45                               Sirayanian, Mr. Orsen    male  22.0      0
# 47                               Skoog, Master. Harald    male   4.0      3
# 49                            Crease, Mr. Ernest James    male  19.0      0
# 50                     Andersson, Miss. Erna Alexandra  female  17.0      4
# 51                                   Kink, Mr. Vincenz    male  26.0      2
# 53                          Goodwin, Miss. Lillian Amy  female  16.0      5
# ..                                                 ...     ...   ...    ...
# 656                                  Lulic, Mr. Nikola    male  27.0      0
# 658                                 Moor, Mrs. (Beila)  female  27.0      0
# 659                       Panula, Master. Urho Abraham    male   2.0      4
# 661            Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0      1
# 663                             Augustsson, Mr. Albert    male  23.0      0
# 664                             Allum, Mr. Owen George    male  18.0      0
# 666                                   Pasic, Mr. Jakob    male  21.0      0
# 667                                    Chip, Mr. Chang    male  32.0      0
# 668                        Alhomaki, Mr. Ilmari Rudolf    male  20.0      0
# 671                         Lemberopolous, Mr. Peter L    male  34.5      0
# 672                                Culumovic, Mr. Jeso    male  17.0      0
# 673                                Abbing, Mr. Anthony    male  42.0      0
# 674                                 Markoff, Mr. Marin    male  35.0      0
# 676            Andersson, Master. Sigvard Harald Elias    male   4.0      4
# 677                                Svensson, Mr. Johan    male  74.0      0
# 678                            Boulos, Miss. Nourelain  female   9.0      1
# 681                         Aks, Mrs. Sam (Leah Rosen)  female  18.0      0
# 684              Baclini, Mrs. Solomon (Latifa Qurban)  female  24.0      0
# 685                            Hansen, Mr. Claus Peter    male  41.0      2
# 692                    Johnson, Master. Harold Theodor    male   4.0      1
# 693                                  Balkic, Mr. Cerin    male  26.0      0
# 696                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 698                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 699                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 700                               Petroff, Mr. Nedelio    male  19.0      0
# 703                                 Markun, Mr. Johann    male  33.0      0
# 704                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 706                             Sutehall, Mr. Henry Jr    male  25.0      0
# 707               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 711                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Fare Embarked
# 0        0   7.2500        S
# 2        0   7.9250        S
# 4        0   8.0500        S
# 6        1  21.0750        S
# 7        2  11.1333        S
# 9        1  16.7000        S
# 11       0   8.0500        S
# 12       5  31.2750        S
# 13       0   7.8542        S
# 15       1  29.1250        Q
# 16       0  18.0000        S
# 19       0   8.0292        Q
# 21       1  21.0750        S
# 22       5  31.3875        S
# 28       0   8.0500        S
# 29       0  18.0000        S
# 30       0  11.2417        C
# 31       0   9.4750        S
# 34       0   7.8792        Q
# 35       0  17.8000        S
# 36       1  39.6875        S
# 37       0   7.8000        S
# 42       0   7.2292        C
# 44       2  46.9000        S
# 45       0   7.2292        C
# 47       2  27.9000        S
# 49       0   8.1583        S
# 50       2   7.9250        S
# 51       0   8.6625        S
# 53       2  46.9000        S
# ..     ...      ...      ...
# 656      0   8.6625        S
# 658      1  12.4750        S
# 659      1  39.6875        S
# 661      0  14.4542        C
# 663      0   7.8542        S
# 664      0   8.3000        S
# 666      0   8.6625        S
# 667      0  56.4958        S
# 668      0   7.9250        S
# 671      0   6.4375        C
# 672      0   8.6625        S
# 673      0   7.5500        S
# 674      0   7.8958        C
# 676      2  31.2750        S
# 677      0   7.7750        S
# 678      1  15.2458        C
# 681      1   9.3500        S
# 684      3  19.2583        C
# 685      0  14.1083        S
# 692      1  11.1333        S
# 693      0   7.8958        S
# 696      0   9.0000        S
# 698      0   7.2250        C
# 699      0   9.8458        S
# 700      0   7.8958        S
# 703      0   7.8958        S
# 704      0  10.5167        S
# 706      0   7.0500        S
# 707      5  29.1250        Q
# 711      0   7.7500        Q
#
# [355 rows x 10 columns])

# %% [markdown]
# <a id='groupby_multiple'></a>
#
# ### Grouping by Multiple Variables
#
# ---
#
# Grouping by more than one column is simple; the `.groupby()` function can accept a list of column names to group by. When you group by more than one column, each subset of the data will correspond to one distinct combination of the grouping columns.
#
# **Create a grouped DataFrame by grouping the Titanic data by "Pclass" and "Survived."**

# %%
doublegrp = df.groupby(['Pclass','Survived'])

# %% [markdown]
# **Print out the length of this grouped DataFrame.**
#
# It is the same length as the unique combinations of "Pclass" and "Survived:" three Pclasses by two survival values.

# %%
len(doublegrp)
# Out:
# 6

# %% [markdown]
# <a id='basic_functions'></a>
#
# ### Applying Basic Functions to Groups
#
# ---
#
# `pandas` makes it easy to apply basic statistical functions to grouped data with built-in functions. For example, assume you have a grouped DataFrame, `grouped`:
#
# ```python
# print grouped.mean()
# print grouped.median()
# print grouped.count()
# print grouped.max()
# ```
#
# We can calculate the mean, median, count, and max of the columns by group.
#
# **Try out these built-in functions on the grouped data you made above.**

# %%
df.groupby('Pclass').mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        464.157609  0.652174  38.105543  0.456522  0.413043  88.048121
# 2        447.156069  0.479769  29.877630  0.427746  0.404624  21.471556
# 3        441.219718  0.239437  25.140620  0.585915  0.456338  13.229435

# %%
df.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Fare  Embarked
# Pclass
# 1               184       184   184  184  184    184    184   184       184
# 2               173       173   173  173  173    173    173   173       173
# 3               355       355   355  355  355    355    355   355       355

# %%
df.groupby('Pclass').size()
# Out:
# Pclass
# 1    184
# 2    173
# 3    355
# dtype: int64

# %% [markdown]
# You can also operate on single columns or subsets of columns across grouped DataFrames using the indexing syntax for standard DataFrames.
#
# **Find the percent of passengers who survived, grouped by where they embarked.**

# %%
dfgrp = df.groupby(['Embarked']).sum()
print dfgrp['Survived'], df.groupby('Embarked').size()
# Out:
# Embarked
# C     79
# Q      8
# S    201
# Name: Survived, dtype: int64 Embarked
# C    130
# Q     28
# S    554
# dtype: int64

# %%
(dfgrp['Survived']/df.groupby('Embarked').size())*100
# Out:
# Embarked
# C    60.769231
# Q    28.571429
# S    36.281588
# dtype: float64

# %% [markdown]
# **Find the average fare and age, grouped by the location embarked as well as the class.**

# %%
df.groupby(['Embarked','Pclass']).mean()[['Fare','Age']]
# Out:
#                        Fare        Age
# Embarked Pclass
# C        1       108.246399  38.027027
#          2        26.811947  22.766667
#          3        11.369927  20.741951
# Q        1        90.000000  38.500000
#          2        12.350000  43.500000
#          3        12.780904  25.937500
# S        1        74.172415  38.152037
#          2        21.075000  30.386731
#          3        13.529451  25.696552

# %% [markdown]
# <a id='removing_hierarchical'></a>
#
# ### Removing the Hierarchical Index
#
# ---
#
# By default, `pandas` will give you back your groups in a hierarchical index format. If this is not what you prefer, you can use the `.reset_index()` function to take your row labels and convert them into columns.
#
# **Remove the hierarchical index for the average fare and age data set you just created, converting "Embarked" and "Pclass" to columns.**

# %%
df.groupby(['Embarked','Pclass']).mean()[['Fare','Age']].reset_index()
# Out:
#   Embarked  Pclass        Fare        Age
# 0        C       1  108.246399  38.027027
# 1        C       2   26.811947  22.766667
# 2        C       3   11.369927  20.741951
# 3        Q       1   90.000000  38.500000
# 4        Q       2   12.350000  43.500000
# 5        Q       3   12.780904  25.937500
# 6        S       1   74.172415  38.152037
# 7        S       2   21.075000  30.386731
# 8        S       3   13.529451  25.696552

# %% [markdown]
# <a id='custom_functions'></a>
#
# ### Applying Custom Functions with `.apply()`
#
# ---
#
# While `pandas` does contain a variety of useful, built-in summary functions, you'll often need to apply a custom function to the data in your groups.
#
# The `.apply()` function takes a function as an argument and applies it to the subsets of data in your DataFrame groups.
#
# **See what happens when you replace the built-in `.mean()` function with `.apply(np.mean)` for the question above.**

# %%
df.groupby(['Embarked','Pclass']).apply(np.mean)
# Out:
#                  PassengerId  Survived  Pclass        Age     SibSp     Parch  \
# Embarked Pclass
# C        1        436.837838  0.716216     1.0  38.027027  0.391892  0.364865
#          2        454.933333  0.533333     2.0  22.766667  0.666667  0.600000
#          3        482.487805  0.439024     3.0  20.741951  0.390244  0.439024
# Q        1        329.500000  0.500000     1.0  38.500000  1.500000  0.000000
#          2        475.000000  0.500000     2.0  43.500000  0.000000  0.000000
#          3        416.000000  0.250000     3.0  25.937500  0.750000  0.458333
# S        1        485.370370  0.611111     1.0  38.152037  0.481481  0.453704
#          2        446.051282  0.474359     2.0  30.386731  0.410256  0.391026
#          3        437.472414  0.210345     3.0  25.696552  0.600000  0.458621
#
#                        Fare
# Embarked Pclass
# C        1       108.246399
#          2        26.811947
#          3        11.369927
# Q        1        90.000000
#          2        12.350000
#          3        12.780904
# S        1        74.172415
#          2        21.075000
#          3        13.529451

# %% [markdown]
# Say we want to determine the mean of fare and age per "Embarked" and "Pclass," but we also want the numbers to be rounded. One way to do this would be to round the columns after we apply the mean function as we did above.
#
# Another way would be to write a custom function to pass into `.apply()`. *The function passed to `.apply()` will run on all of the subsets of data.*
#
# **Write a function that will take the mean of columns in a data set and round the values.**

# %%
def round2(col):
    return np.round(np.mean(col),0)

# %%
round2(df['Fare'])
# Out:
# 35.0

# %%
df.groupby(['Embarked','Pclass']).apply(round2)
# Out:
#                  PassengerId  Survived  Pclass    Age  SibSp  Parch    Fare
# Embarked Pclass
# C        1            436.84      0.72     1.0  38.03   0.39   0.36  108.25
#          2            454.93      0.53     2.0  22.77   0.67   0.60   26.81
#          3            482.49      0.44     3.0  20.74   0.39   0.44   11.37
# Q        1            329.50      0.50     1.0  38.50   1.50   0.00   90.00
#          2            475.00      0.50     2.0  43.50   0.00   0.00   12.35
#          3            416.00      0.25     3.0  25.94   0.75   0.46   12.78
# S        1            485.37      0.61     1.0  38.15   0.48   0.45   74.17
#          2            446.05      0.47     2.0  30.39   0.41   0.39   21.08
#          3            437.47      0.21     3.0  25.70   0.60   0.46   13.53

# %%
df.groupby(['Embarked','Pclass']).apply(lambda x: np.round(np.mean(x),2))
# Out:
#                  PassengerId  Survived  Pclass    Age  SibSp  Parch    Fare
# Embarked Pclass
# C        1            436.84      0.72     1.0  38.03   0.39   0.36  108.25
#          2            454.93      0.53     2.0  22.77   0.67   0.60   26.81
#          3            482.49      0.44     3.0  20.74   0.39   0.44   11.37
# Q        1            329.50      0.50     1.0  38.50   1.50   0.00   90.00
#          2            475.00      0.50     2.0  43.50   0.00   0.00   12.35
#          3            416.00      0.25     3.0  25.94   0.75   0.46   12.78
# S        1            485.37      0.61     1.0  38.15   0.48   0.45   74.17
#          2            446.05      0.47     2.0  30.39   0.41   0.39   21.08
#          3            437.47      0.21     3.0  25.70   0.60   0.46   13.53

# %% [markdown]
# **Apply your custom function to the grouped data.**

# %% [markdown]
# Functions that can be applied to a DataFrame and return a DataFrame can also be applied to *groups* of DataFrames.
#
# **For example, write a function that will return the subset of the Titanic data set with the top five paying female passsengers.**

# %%
def topfemale(sub):
    return sub[sub['Sex']=='female'].sort_values('Fare', ascending=False).head(5)

# %% [markdown]
# **Group the Titanic data by "Survived" and apply your function to extract the top paying females.**

# %%
df.groupby('Survived').apply(topfemale)
# Out:
#               PassengerId  Survived  Pclass  \
# Survived
# 0        395          499         0       1
#          239          298         0       1
#          535          679         0       3
#          53            72         0       3
#          504          639         0       3
# 1        207          259         1       1
#          273          342         1       1
#          66            89         1       1
#          247          312         1       1
#          588          743         1       1
#
#                                                          Name     Sex   Age  \
# Survived
# 0        395  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
#          239                     Allison, Miss. Helen Loraine  female   2.0
#          535          Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0
#          53                        Goodwin, Miss. Lillian Amy  female  16.0
#          504           Panula, Mrs. Juha (Maria Emilia Ojala)  female  41.0
# 1        207                                 Ward, Miss. Anna  female  35.0
#          273                   Fortune, Miss. Alice Elizabeth  female  24.0
#          66                        Fortune, Miss. Mabel Helen  female  23.0
#          247                       Ryerson, Miss. Emily Borie  female  18.0
#          588            Ryerson, Miss. Susan Parker "Suzette"  female  21.0
#
#               SibSp  Parch      Fare Embarked
# Survived
# 0        395      1      2  151.5500        S
#          239      1      2  151.5500        S
#          535      1      6   46.9000        S
#          53       5      2   46.9000        S
#          504      0      5   39.6875        S
# 1        207      0      0  512.3292        C
#          273      3      2  263.0000        S
#          66       3      2  263.0000        S
#          247      2      2  262.3750        C
#          588      2      2  262.3750        C

# %% [markdown]
# <a id='basic_plotting'></a>
#
# ### Plotting Basic Histograms with Groups
#
# ---
#
# We can leverage the power of `pandas` even more by mixing its plotting capabilities with its grouping capabilities.
#
# **First, find the number of passengers per "PClass" by using `.groupby()` and `.size()`.**

# %%
df.groupby('Pclass').size()
# Out:
# Pclass
# 1    184
# 2    173
# 3    355
# dtype: int64

# %% [markdown]
# Here we have a Series object with the counts of the passengers-per-class group. It's easy to create a histogram of these counts by appending `.plot(kind="bar", color="g", width=0.85)`.

# %%
df.groupby('Pclass').size().plot(kind='bar', color='g', width=0.85)

# %% [markdown]
# **Plot the average fare per sex and class as a histogram.**

# %%
df.groupby(['Sex','Pclass']).mean()['Fare']
# Out:
# Sex     Pclass
# female  1         108.619680
#         2          21.951070
#         3          15.875369
# male    1          71.142781
#         2          21.113131
#         3          12.162695
# Name: Fare, dtype: float64

# %%
df.groupby(['Sex','Pclass']).mean()['Fare'].plot(kind='bar', color='g', figsize=(12,5))
plt.legend(loc=1)

# %% [markdown]
# <a id='grouped_hists'></a>
#
# ### Grouped Histograms with `pandas`
#
# ---
#
# In the chart we just made, each bar represents a distinct combination of our groups in `.groupby()`. This is fine, but it would be a more visually appealing and informative chart if we represented each group with a different color and made a grouped bar chart.
#
# **Calculate the mean of fare by "Pclass" and "Sex" using `.groupby()`, assign it to a variable, and print it out.**

# %% [markdown]
# There is another built-in function for `pandas` objects called `.unstack()`. When we have a hierarchical index like we do above with "Pclass" as the broader category and "Sex" as the subcategory, the `.unstack()` command will attempt to move the subcategory from index to column representation.
#
# This is a way to move from a "long" to a "wide" column format.
#
# **Use the `.unstack()` function on your mean fare variable.**

# %% [markdown]
# **Now, use the plot function on the unstacked data to create a bar chart.**

# %% [markdown]
# If you add the keyword variable `stacked=True`, it will instead stack the bars within the broader "Pclass" category.

# %% [markdown]
# <a id='independent_practice'></a>
#
# ### Independent Practice
#
# ---
#
# Now that you've covered the basics of grouping, applying functions, aggregating data, and `pandas` plotting with grouped data, [open up the practice notebook](./practice/practice_pandas_grouping.ipynb)  and explore the UFO sightings data!

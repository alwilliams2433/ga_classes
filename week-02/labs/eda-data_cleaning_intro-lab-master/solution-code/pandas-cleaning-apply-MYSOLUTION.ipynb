# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Lab: Cleaning Rock Song Data
#
# _Authors: Dave Yerrington (SF)_
#
# ---

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Load `rock.csv` and do an initial examination of its data columns.

# %%
rockfile = "../datasets/rock.csv"

# %%
# Load the data.

df = pd.read_csv(rockfile)

# %%
# Look at the information regarding its columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# Song Clean      2230 non-null object
# ARTIST CLEAN    2230 non-null object
# Release Year    1653 non-null object
# COMBINED        2230 non-null object
# First?          2230 non-null int64
# Year?           2230 non-null int64
# PlayCount       2230 non-null int64
# F*G             2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.4+ KB

# %%
df.dtypes
# Out:
# Song Clean      object
# ARTIST CLEAN    object
# Release Year    object
# COMBINED        object
# First?           int64
# Year?            int64
# PlayCount        int64
# F*G              int64
# dtype: object

# %%
df.sample(10)
# Out:
#                         Song Clean    ARTIST CLEAN Release Year  \
# 2210  Beer Drinkers & Hell Raisers          ZZ Top         1973
# 1729           Don't Bring Me Down     The Animals         1966
# 154                     Rebel Yell      Billy Idol         1984
# 1467                 Gimme Shelter  Rolling Stones         1969
# 1826          The Fool On The Hill     The Beatles         1967
# 1699           Life During Wartime   Talking Heads         1979
# 1592               Pulling Mussels         Squeeze         1980
# 2148                 Summer Nights       Van Halen         1986
# 1550                   The Warrior         Scandal         1984
# 31                        Sin City           AC/DC          NaN
#
#                                     COMBINED  First?  Year?  PlayCount  F*G
# 2210  Beer Drinkers & Hell Raisers by ZZ Top       1      1          8    8
# 1729      Don't Bring Me Down by The Animals       1      1          1    1
# 154                 Rebel Yell by Billy Idol       1      1         89   89
# 1467         Gimme Shelter by Rolling Stones       1      1         96   96
# 1826     The Fool On The Hill by The Beatles       1      1          2    2
# 1699    Life During Wartime by Talking Heads       1      1         23   23
# 1592              Pulling Mussels by Squeeze       1      1          2    2
# 2148              Summer Nights by Van Halen       1      1          4    4
# 1550                  The Warrior by Scandal       1      1          5    5
# 31                         Sin City by AC/DC       1      0          1    0

# %% [markdown]
# ### 2.  Clean up the column names.
#
# Let's clean up the column names. There are two ways we can accomplish this:
#
# #### 2.A Change the column names when you import the data using `pd.read_csv()`.
#
# Notice that, when passing `names=[..A LIST OF STRING..]` with a number of columns that matches the number of strings in the passed list, you replace the column names.
#
# NOTE: When you create custom column names, the first row of the `.csv` already represents a header. It is important to tell `pandas` to skip that row. The `skiprows=1` keyword argument to `read_csv()` will tell `pandas` to skip the first row.

# %%
df.columns
# Out:
# Index([u'Song Clean', u'ARTIST CLEAN', u'Release Year', u'COMBINED', u'First?',
#        u'Year?', u'PlayCount', u'F*G'],
#       dtype='object')

# %%
import string
# the string library has default strings that contain all letters or numbers
uppercase = string.ascii_uppercase
lowercase = string.ascii_lowercase

df.columns = [''.join([c.lower() for c in column if c in uppercase+lowercase]) for column in df.columns]

# %%
df.columns
# Out:
# Index([u'songclean', u'artistclean', u'releaseyear', u'combined', u'first',
#        u'year', u'playcount', u'fg'],
#       dtype='object')

# %% [markdown]
# #### 2.B Change column names using the `.rename()` function.
#
# The `.rename()` function takes an argument, `columns=name_dict`, in which `name_dict` is a dictionary containing the original column names as keys and the new column names as values.

# %%
# Change the column names using the `.rename()` function.
df = df.rename(columns = lambda column : ''.join([c.lower() for c in column if c in uppercase+lowercase]))

# %%
df.head(2)
# Out:
#           songclean  artistclean releaseyear                         combined  \
# 0  Caught Up in You  .38 Special        1982  Caught Up in You by .38 Special
# 1      Fantasy Girl  .38 Special         NaN      Fantasy Girl by .38 Special
#
#    first  year  playcount  fg
# 0      1     1         82  82
# 1      1     0          3   0

# %% [markdown]
# #### 2.C Reassigning the `.columns` attribute of a DataFrame.
#
# You can also just reassign the `.columns` attribute to a list of strings containing the new column names.
#
# The only caveat with reassigning `.columns` is that you have to reassign all of the column names at once. You can't partially replace a value by working on `.columns` directly. You have to reassign `.columns` with a list of equal length.

# %%
# Replace the column names by reassigning the `.columns` attribute.
df.columns = [''.join([c.lower() for c in column if c in uppercase+lowercase]) for column in df.columns]

# %%
df.columns
# Out:
# Index([u'songclean', u'artistclean', u'releaseyear', u'combined', u'first',
#        u'year', u'playcount', u'fg'],
#       dtype='object')

# %% [markdown]
# ### 3. Subsetting data where null values exist.
#
# We have mixed `str` and `NaN` values in the `release` column. `NaN` stands for "not a number" and is the way `pandas` handles "nulls" or nonexistent data. We can use the `.isnull()` method of a Series to find null values.
#
# Print the header of the data subset to where the `release` column is null values.

# %%
df.columns
# Out:
# Index([u'songclean', u'artistclean', u'releaseyear', u'combined', u'first',
#        u'year', u'playcount', u'fg'],
#       dtype='object')

# %%
# Show records where df['release'] is null
df[df['releaseyear'].isnull()].head()
# Out:
#                  songclean  artistclean releaseyear  \
# 1             Fantasy Girl  .38 Special         NaN
# 10   Baby, Please Don't Go        AC/DC         NaN
# 13  CAN'T STOP ROCK'N'ROLL        AC/DC         NaN
# 16        Girls Got Rhythm        AC/DC         NaN
# 24         Let's Get It Up        AC/DC         NaN
#
#                            combined  first  year  playcount  fg
# 1       Fantasy Girl by .38 Special      1     0          3   0
# 10   Baby, Please Don't Go by AC/DC      1     0          1   0
# 13  CAN'T STOP ROCK'N'ROLL by AC/DC      1     0          5   0
# 16        Girls Got Rhythm by AC/DC      1     0         24   0
# 24         Let's Get It Up by AC/DC      1     0          4   0

# %%
df[~df['releaseyear'].isnull()].head()
# Out:
#                 songclean   artistclean releaseyear  \
# 0        Caught Up in You   .38 Special        1982
# 2         Hold On Loosely   .38 Special        1981
# 3  Rockin' Into the Night   .38 Special        1980
# 4       Art For Arts Sake          10cc        1975
# 5              Kryptonite  3 Doors Down        2000
#
#                                 combined  first  year  playcount  fg
# 0        Caught Up in You by .38 Special      1     1         82  82
# 2         Hold On Loosely by .38 Special      1     1         85  85
# 3  Rockin' Into the Night by .38 Special      1     1         18  18
# 4              Art For Arts Sake by 10cc      1     1          1   1
# 5             Kryptonite by 3 Doors Down      1     1         13  13

# %% [markdown]
# ### 4. Update slices of your DataFrame based on mask selection/slices.
#
# In many scenarios, we want to upate values in our DataFrame according to criteria. Let's say we wanted to set all of the null values in `release` to 0.
#
# With newer versions of `pandas`, in order to manipulate data in the original DataFrame, we have to use `.loc` while performing reassignment using a mask and an index.
#
# For example, the following won't always work:
# ```python
# df[row_mask]['column_name'] = new_value
# ```
#
# The best way to accomplish the same task is:
# ```python
# df.loc[row_mask, 'column_name'] = new_value
# ```
#
# For multiple column assignment, you would use:
# ```python
# df.loc[row_mask, ['col_1', 'col_2', 'col_3']] = new_value
# ```
#
# #### 4.A Let's try it out. Make all of the null values in `release` 0.

# %%
# Replace release nulls with 0

# %%
df[df['releaseyear'].isnull()].index
# Out:
# Int64Index([   1,   10,   13,   16,   24,   25,   26,   29,   31,   35,
#             ...
#             2203, 2205, 2206, 2208, 2215, 2216, 2218, 2221, 2222, 2225],
#            dtype='int64', length=577)

# %%
df.loc[df[df['releaseyear'].isnull()].index, 'releaseyear'] = 0

# %%
# cheat df['releaseyear'] = df['releaseyear'].fillna(0)

# %% [markdown]
# #### 4.B Verify that `release` contains no null values.

# %%
df[df['releaseyear'].isnull()]
# Out:
# Empty DataFrame
# Columns: [songclean, artistclean, releaseyear, combined, first, year, playcount, fg]
# Index: []

# %% [markdown]
# ### 5. Ensure that the data types of the columns make sense.
#
# Verifying column data types is a critical part of data munging. If columns have the wrong data type, then there is usually corrupted or incorrect data in some of the observations.
#
# #### 5.A Look at the data types for the columns. Are any incorrect given what the data represents?

# %%
# A:

df.dtypes
# Out:
# songclean      object
# artistclean    object
# releaseyear    object
# combined       object
# first           int64
# year            int64
# playcount       int64
# fg              int64
# dtype: object

# %%
df.sample(5)
# Out:
#                   songclean             artistclean releaseyear  \
# 809           What You Need                    INXS        1985
# 1218  Mama, I'm Coming Home           Ozzy Osbourne        1991
# 1267     With a Little Luck  Paul McCartney & Wings           0
# 751               Civil War           Guns N' Roses        1991
# 799         ALL YOU ZOMBIES                 Hooters        1985
#
#                                           combined  first  year  playcount  fg
# 809                          What You Need by INXS      1     1         28  28
# 1218        Mama, I'm Coming Home by Ozzy Osbourne      1     1         31  31
# 1267  With a Little Luck by Paul McCartney & Wings      1     0          2   0
# 751                     Civil War by Guns N' Roses      1     1          1   1
# 799                     ALL YOU ZOMBIES by Hooters      1     1          4   4

# %% [markdown]
# ##### COMMENT: releaseyear as object?!?!

# %% [markdown]
# ### 6. Investigate and clean up the `release` column.
#
# The `release` column is a string data type when it should be an integer.
#
# #### 6.A Figure out what value(s) are causing the `release` column to be encoded as a string instead of an integer.

# %%
df['releaseyear'].unique()
# Out:
# array(['1982', 0, '1981', '1980', '1975', '2000', '2002', '1992', '1985',
#        '1993', '1976', '1995', '1979', '1984', '1977', '1990', '1986',
#        '1974', '2014', '1987', '1973', '2001', '1989', '1997', '1971',
#        '1972', '1994', '1970', '1966', '1965', '1983', '1955', '1978',
#        '1969', '1999', '1968', '1988', '1962', '2007', '1967', '1958',
#        '1071', '1996', '1991', '2005', '2011', '2004', '2012', '2003',
#        '1998', '2008', '1964', '2013', '2006', 'SONGFACTS.COM', '1963',
#        '1961'], dtype=object)

# %%
for c in df['releaseyear']:
    try:
        float(c)
    except:
        print(c)
# Out:
# SONGFACTS.COM

# %% [markdown]
# #### 6.B Look at the rows in which there is incorrect data in the `release` column.

# %%
df[df['releaseyear']=='SONGFACTS.COM']
# Out:
#            songclean     artistclean    releaseyear  \
# 1504  Bullfrog Blues  Rory Gallagher  SONGFACTS.COM
#
#                               combined  first  year  playcount  fg
# 1504  Bullfrog Blues by Rory Gallagher      1     1          1   1

# %% [markdown]
# #### 6.C. Clean up the data. Normally we may replace the offending data with null np.nan values, however we previously converted all of the nan values in the release column to zeros so we might as well continue with the same practice. Replacing with 0 (or nan) will allow us to convert the column to numeric.

# %%
df.loc[df[df['releaseyear']=='SONGFACTS.COM'].index, 'releaseyear'] = np.nan

# %%
df['releaseyear'] = df['releaseyear'].astype(float)

# %%
df.dtypes
# Out:
# songclean       object
# artistclean     object
# releaseyear    float64
# combined        object
# first            int64
# year             int64
# playcount        int64
# fg               int64
# dtype: object

# %% [markdown]
# ### 7. Get summary statistics for the `release` column using the `.describe()` function.
#
# Now that the `release` column is finally a numeric data type, we can apply the `.describe()` function.
#
# #### 7.A Print out the summary stats for the `release` column. What is the earliest and latest release date?

# %%
# A:
df['releaseyear'].describe()
# Out:
# count    2229.000000
# mean     1465.988784
# std       866.834789
# min         0.000000
# 25%         0.000000
# 50%      1973.000000
# 75%      1981.000000
# max      2014.000000
# Name: releaseyear, dtype: float64

# %%
df[df['releaseyear']>0]['releaseyear'].describe()
# Out:
# count    1652.000000
# mean     1978.019976
# std        24.191247
# min      1071.000000
# 25%      1971.000000
# 50%      1977.000000
# 75%      1984.000000
# max      2014.000000
# Name: releaseyear, dtype: float64

# %% [markdown]
# #### 7.B Based on the summary statistics, is there anything else wrong with the `release` column?

# %% [markdown]
# _Looking at the DataFrame that contains the year 1071, we can see that the year was probably corrupted and should be replaced with something else if possible._

# %% [markdown]
# ### 8. Make changes and investigate using custom functions with `.apply()`.
#
# Let's say we want to traverse every single row in our data set and apply a function to that row.
#
# #### 8.A Write a function that will take a row of a DataFrame and print out the song, artist, and whether or not the release date is < 1970.

# %%
# A:

def print_info(row):
    print(row['songclean'],row['artistclean'],row['releaseyear']<1970)

# %% [markdown]
# #### 8.B Using the `.apply()` function, apply the function you wrote to the first four rows of the DataFrame.
#
# You will need to tell the `apply` function to operate row by row. Setting the keyword argument as `axis=1` indicates that the function should be applied to each row individually.

# %%
# THIS IS BY COLUMNS --> ERROR!
# df.apply(print_info, axis=0)

# %%
# This is by rows
df.apply(print_info, axis=1)
# Out:
# ('Caught Up in You', '.38 Special', False)
# ('Fantasy Girl', '.38 Special', True)
# ('Hold On Loosely', '.38 Special', False)
# ("Rockin' Into the Night", '.38 Special', False)
# ('Art For Arts Sake', '10cc', False)
# ('Kryptonite', '3 Doors Down', False)
# ('Loser', '3 Doors Down', False)
# ("When I'm Gone", '3 Doors Down', False)
# ("What's Up?", '4 Non Blondes', False)
# ('Take On Me', 'a-ha', False)
# ("Baby, Please Don't Go", 'AC/DC', True)
# ('Back In Black', 'AC/DC', False)
# ('Big Gun', 'AC/DC', False)
# ("CAN'T STOP ROCK'N'ROLL", 'AC/DC', True)
# ('Dirty Deeds Done Dirt Cheap', 'AC/DC', False)
# ('For Those About To Rock', 'AC/DC', False)
# ('Girls Got Rhythm', 'AC/DC', True)
# ('Hard As A Rock', 'AC/DC', False)
# ('Have a Drink On Me', 'AC/DC', False)
# ('Hells Bells', 'AC/DC', False)
# ('Highway To Hell', 'AC/DC', False)
# ("It's A Long Way To The Top", 'AC/DC', False)
# ('Jailbreak', 'AC/DC', False)
# ('Let There Be Rock', 'AC/DC', False)
# ("Let's Get It Up", 'AC/DC', True)
# ('Live Wire', 'AC/DC', True)
# ('Moneytalks', 'AC/DC', True)
# ('Night Prowler', 'AC/DC', False)
# ("Rock and Roll Ain't Noise Pollution", 'AC/DC', False)
# ('Shoot To Thrill', 'AC/DC', True)
# ('Shot Down In Flames', 'AC/DC', False)
# ('Sin City', 'AC/DC', True)
# ('T.N.T.', 'AC/DC', False)
# ('Thunderstruck', 'AC/DC', False)
# ('Touch Too Much', 'AC/DC', False)
# ('What Do You Do For Money Honey', 'AC/DC', True)
# ('Who Made Who', 'AC/DC', False)
# ('Whole Lotta Rosie', 'AC/DC', False)
# ('You Shook Me All Night Long', 'AC/DC', False)
# ('How Long', 'Ace', False)
# ('Dog On A Leash', 'Adelitas Way', False)
# ('Angel', 'Aerosmith', False)
# ("Baby, Please Don't Go", 'Aerosmith', True)
# ('Back in the Saddle', 'Aerosmith', False)
# ('Big Ten Inch', 'Aerosmith', False)
# ('Come Together', 'Aerosmith', True)
# ('Crazy', 'Aerosmith', False)
# ("Cryin'", 'Aerosmith', False)
# ('Draw The Line', 'Aerosmith', False)
# ('Dream On', 'Aerosmith', False)
# ('Dude (Looks Like a Lady)', 'Aerosmith', False)
# ('Jaded', 'Aerosmith', False)
# ("Janie's Got A Gun", 'Aerosmith', False)
# ('Kings and Queens', 'Aerosmith', True)
# ('Last Child', 'Aerosmith', False)
# ('Let the Music Do the Talking', 'Aerosmith', False)
# ("Livin' On The Edge", 'Aerosmith', False)
# ('Love In An Elevator', 'Aerosmith', False)
# ('Mama Kin', 'Aerosmith', False)
# ('No More No More', 'Aerosmith', False)
# ('One Way Street', 'Aerosmith', True)
# ('Pink', 'Aerosmith', False)
# ('Rag Doll', 'Aerosmith', False)
# ('Same Old Song and Dance', 'Aerosmith', False)
# ('Seasons of Wither', 'Aerosmith', False)
# ('Sweet Emotion', 'Aerosmith', False)
# ('The Other Side', 'Aerosmith', True)
# ('Toys in the Attic', 'Aerosmith', False)
# ("Train Kept A-Rollin'", 'Aerosmith', False)
# ('Walk This Way', 'Aerosmith', False)
# ('What It Takes', 'Aerosmith', False)
# ('You See Me Crying', 'Aerosmith', True)
# ('Hand In My Pocket', 'Alanis Morissette', False)
# ('You Oughta Know', 'Alanis Morissette', False)
# ('Black Velvet', 'Alannah Myles', False)
# ('Fantasy', 'Aldo Nova', True)
# ('BE MY LOVER', 'Alice Cooper', True)
# ('Billion Dollar Babies', 'Alice Cooper', False)
# ('Eighteen', 'Alice Cooper', False)
# ('Elected', 'Alice Cooper', False)
# ('House Of Fire', 'Alice Cooper', True)
# ("I'm Eighteen", 'Alice Cooper', False)
# ('No More Mr. Nice Guy', 'Alice Cooper', False)
# ("School's Out", 'Alice Cooper', False)
# ('Under My Wheels', 'Alice Cooper', False)
# ('Welcome To My Nightmare', 'Alice Cooper', False)
# ('Down in a Hole', 'Alice In Chains', False)
# ('Man In The Box', 'Alice In Chains', False)
# ('No Excuses', 'Alice In Chains', False)
# ('Rooster', 'Alice In Chains', False)
# ('Them Bones', 'Alice In Chains', False)
# ('Would?', 'Alice In Chains', False)
# ("Ain't Wastin' Time No More", 'Allman Brothers Band', False)
# ('Blue Sky', 'Allman Brothers Band', False)
# ('Good Clean Fun', 'Allman Brothers Band', False)
# ('In Memory Of Elizabeth Reed', 'Allman Brothers Band', False)
# ('Jessica', 'Allman Brothers Band', False)
# ('Melissa', 'Allman Brothers Band', False)
# ('Midnight Rider', 'Allman Brothers Band', False)
# ('No One to Run With', 'Allman Brothers Band', False)
# ('One Way Out', 'Allman Brothers Band', True)
# ("Ramblin' Man", 'Allman Brothers Band', False)
# ('Southbound', 'Allman Brothers Band', True)
# ('Statesboro Blues', 'Allman Brothers Band', False)
# ("Whippin' Post", 'Allman Brothers Band', True)
# ('A Horse With No Name', 'America', False)
# ('Sister Golden Hair', 'America', False)
# ('Ventura Highway', 'America', False)
# ("Don't Bring Me Down", 'Animals II', True)
# ("Don't Let Me Be Misunderstood", 'Animals II', True)
# ('Immigrant Song', 'Ann Wilson', True)
# ('Roller', 'April Wine', True)
# ('Hold Your Head Up', 'Argent', False)
# ('Coming into Los Angeles', 'Arlo Guthrie', True)
# ('Wayside', 'Artful Dodger', True)
# ('Heat of the Moment', 'Asia', False)
# ('Only Time Will Tell', 'Asia', False)
# ('So Into You', 'Atlanta Rhythm Section', False)
# ('Spooky', 'Atlanta Rhythm Section', True)
# ('Like a Stone', 'Audioslave', False)
# ('Blondes In Black Cars', 'Autograph', True)
# ('Turn Up the Radio', 'Autograph', False)
# ('Rock And Roll Party In The Streets', 'Axe', True)
# ('Let It Ride', 'Bachman-Turner Overdrive', False)
# ('Roll On Down The Highway', 'Bachman-Turner Overdrive', True)
# ("Takin' Care Of Business", 'Bachman-Turner Overdrive', False)
# ("You Ain't Seen Nothin' Yet", 'Bachman-Turner Overdrive', False)
# ('Bad Company', 'Bad Company', False)
# ("Burnin' Sky", 'Bad Company', False)
# ("Can't Get Enough", 'Bad Company', False)
# ("Feel Like Makin' Love", 'Bad Company', True)
# ('Gone Gone Gone', 'Bad Company', True)
# ("Good Lovin' Gone Bad", 'Bad Company', True)
# ("Movin' On", 'Bad Company', True)
# ('Ready For Love', 'Bad Company', True)
# ("Rock 'n' Roll Fantasy", 'Bad Company', True)
# ('Rock Steady', 'Bad Company', True)
# ('Run With The Pack', 'Bad Company', True)
# ('Seagull', 'Bad Company', False)
# ('Shooting Star', 'Bad Company', False)
# ('Silver, Blue And Gold', 'Bad Company', True)
# ('When I See You Smile', 'Bad English', False)
# ('No Matter What', 'Badfinger', False)
# ('Walks Like A Woman', 'Baton Rouge', True)
# ('(You Gotta) Fight for Your Right (To Party)', 'Beastie Boys', False)
# ('No Sleep Till Brooklyn', 'Beastie Boys', False)
# ('Loser', 'Beck', False)
# ('In a Big Country', 'Big Country', False)
# ('Rock Around the Clock', 'Bill Haley', True)
# ("AIN'T NO SUNSHINE", 'Bill Withers', False)
# ('Cradle of Love', 'Billy Idol', False)
# ('Dancing With Myself', 'Billy Idol', False)
# ('Eyes Without a Face', 'Billy Idol', False)
# ('Mony Mony', 'Billy Idol', True)
# ('Rebel Yell', 'Billy Idol', False)
# ('White Wedding', 'Billy Idol', False)
# ('Allentown', 'Billy Joel', False)
# ('Big Shot', 'Billy Joel', False)
# ('Captain Jack', 'Billy Joel', False)
# ("Don't Ask Me Why", 'Billy Joel', True)
# ('Goodnight Saigon', 'Billy Joel', False)
# ("It's Still Rock And Roll To Me", 'Billy Joel', False)
# ('Miami 2017 {seen The Lights Go Out On Broadway} (live 1', 'Billy Joel', False)
# ("Movin' Out (Anthony's Song)", 'Billy Joel', False)
# ('My Life', 'Billy Joel', False)
# ('New York State Of Mind', 'Billy Joel', False)
# ('Only The Good Die Young', 'Billy Joel', False)
# ('Piano Man', 'Billy Joel', False)
# ('Prelude/angry Young Man', 'Billy Joel', True)
# ('Scenes From An Italian Restaurant', 'Billy Joel', False)
# ("SHE'S ALWAYS A WOMAN", 'Billy Joel', False)
# ('Sometimes A Fantasy', 'Billy Joel', False)
# ('The Ballad Of Billy The Kid', 'Billy Joel', False)
# ('The Stranger', 'Billy Joel', False)
# ('You May Be Right', 'Billy Joel', False)
# ('Baby Come Back', 'Billy Rankin', True)
# ('Everybody Wants You', 'Billy Squier', True)
# ('In the Dark', 'Billy Squier', True)
# ('Lonely Is the Night', 'Billy Squier', False)
# ('My Kinda Lover', 'Billy Squier', True)
# ('Rock Me Tonight', 'Billy Squier', False)
# ("She's a Runner", 'Billy Squier', True)
# ('The Stroke', 'Billy Squier', False)
# ('Children Of The Sun', 'Billy Thorpe', True)
# ('Fairies Wear Boots', 'Black Sabbath', False)
# ('Heaven and Hell', 'Black Sabbath', False)
# ('Iron Man', 'Black Sabbath', False)
# ('N.i.b.', 'Black Sabbath', False)
# ('Neon Knights', 'Black Sabbath', False)
# ('Paranoid', 'Black Sabbath', False)
# ('Sweet Leaf', 'Black Sabbath', False)
# ('The Wizard', 'Black Sabbath', False)
# ('War Pigs', 'Black Sabbath', False)
# ('Highway Song', 'Blackfoot', True)
# ('Train, Train', 'Blackfoot', False)
# ("Can't Find My Way Home", 'Blind Faith', True)
# ('Presence of the Lord', 'Blind Faith', True)
# ('No Rain', 'Blind Melon', False)
# ('Presence of the Lord', 'Blind Melon', True)
# ('All the Small Things', 'Blink-182', False)
# ('Call Me', 'Blondie', False)
# ('Heart of Glass', 'Blondie', False)
# ('One Way Or Another', 'Blondie', False)
# ("(Don't Fear) The Reaper", 'Blue Oyster Cult', False)
# ('Bucks Boogie', 'Blue Oyster Cult', True)
# ("Burnin' for You", 'Blue Oyster Cult', False)
# ('Godzilla', 'Blue Oyster Cult', False)
# ('I Love the Night', 'Blue Oyster Cult', False)
# ('Summertime Blues', 'Blue Oyster Cult', True)
# ('Song 2', 'Blur', False)
# ('Just Like A Woman', 'Bob Dylan', True)
# ("Knockin' On Heaven's Door", 'Bob Dylan', False)
# ('Like a Rolling Stone', 'Bob Dylan', True)
# ('Positively 4th Street', 'Bob Dylan', True)
# ('Subterranean Homesick Blues', 'Bob Dylan', True)
# ('Tangled Up In Blue', 'Bob Dylan', False)
# ('Exodus', 'Bob Marley', True)
# ('Jamming', 'Bob Marley', True)
# ('No Woman, No Cry', 'Bob Marley', False)
# ('One Love', 'Bob Marley', False)
# ('Stir It Up', 'Bob Marley', True)
# ('Three Little Birds', 'Bob Marley', True)
# ('Against The Wind', 'Bob Seger', False)
# ("Betty Lou's Gettin' Out Tonigh", 'Bob Seger', True)
# ('Come to Poppa', 'Bob Seger', True)
# ('Feel Like a Number', 'Bob Seger', True)
# ('Fire Down Below', 'Bob Seger', False)
# ('Get Out of Denver', 'Bob Seger', True)
# ('Her Strut', 'Bob Seger', False)
# ('Hollywood Nights', 'Bob Seger', False)
# ('Horizontal Bop', 'Bob Seger', True)
# ('Katmandu', 'Bob Seger', False)
# ('Mainstreet', 'Bob Seger', False)
# ('Night Moves', 'Bob Seger', False)
# ('Old Time Rock & Roll', 'Bob Seger', False)
# ("Ramblin' Gamblin' Man", 'Bob Seger', True)
# ('Rock And Roll Never Forgets', 'Bob Seger', False)
# ('Roll Me Away', 'Bob Seger', True)
# ('Still the Same', 'Bob Seger', False)
# ('Sunspot Baby', 'Bob Seger', True)
# ('The Fire Down Below', 'Bob Seger', True)
# ("Travelin' Man", 'Bob Seger', True)
# ('Turn On Your Love Light', 'Bob Seger', True)
# ('Turn The Page', 'Bob Seger', False)
# ("We've Got Tonite", 'Bob Seger', False)
# ("You'll Accompany Me", 'Bob Seger', True)
# ('Hypnotized', 'Bob Welch', True)
# ('Bad Medicine', 'Bon Jovi', False)
# ('Blaze of Glory', 'Bon Jovi', False)
# ('Born To Be My Baby', 'Bon Jovi', False)
# ('Lay Your Hands On Me', 'Bon Jovi', False)
# ("Livin' On A Prayer", 'Bon Jovi', False)
# ('Raise Your Hands', 'Bon Jovi', True)
# ('Runaway', 'Bon Jovi', False)
# ("She Don't Know Me", 'Bon Jovi', True)
# ('Wanted Dead or Alive', 'Bon Jovi', False)
# ('You Give Love A Bad Name', 'Bon Jovi', False)
# ('Wait For You', 'Bonham', True)
# ('Green Onions', "Booker T. and the MG's", True)
# ("A Man I'll Never Be", 'Boston', True)
# ('Amanda', 'Boston', False)
# ('Cool The Engines', 'Boston', True)
# ("Don't Look Back", 'Boston', False)
# ("Feelin' Satisfied", 'Boston', True)
# ('Foreplay (Long Time)', 'Boston', False)
# ('Hitch A Ride', 'Boston', False)
# ('Let Me Take You Home Tonight', 'Boston', False)
# ('More Than a Feeling', 'Boston', False)
# ('Party', 'Boston', True)
# ('Peace of Mind', 'Boston', False)
# ('Rock & Roll Band', 'Boston', False)
# ("Smokin'", 'Boston', False)
# ('Something About You', 'Boston', True)
# ("The Journey/It's Easy", 'Boston', True)
# ('Used To Bad News', 'Boston', True)
# ("We're Ready", 'Boston', True)
# ('Lido Shuffle', 'Boz Scaggs', False)
# ('Lowdown', 'Boz Scaggs', False)
# ('Tarkio Road', 'Brewer & Shipley', True)
# ('The Way It Is', 'Bruce Hornsby & The Range', False)
# ('Atlantic City', 'Bruce Springsteen', False)
# ('Backstreets', 'Bruce Springsteen', False)
# ('Badlands', 'Bruce Springsteen', False)
# ('Blinded By the Light', 'Bruce Springsteen', False)
# ('Born In the U.S.A.', 'Bruce Springsteen', False)
# ('Born To Run', 'Bruce Springsteen', False)
# ('Cover Me', 'Bruce Springsteen', False)
# ('Dancing In the Dark', 'Bruce Springsteen', False)
# ('Glory Days', 'Bruce Springsteen', False)
# ("Growin' Up", 'Bruce Springsteen', False)
# ('Hungry Heart', 'Bruce Springsteen', False)
# ("I'm On Fire", 'Bruce Springsteen', False)
# ("It's Hard to Be a Saint in the City", 'Bruce Springsteen', False)
# ('Jersey Girl', 'Bruce Springsteen', True)
# ('Jungleland', 'Bruce Springsteen', False)
# ('Pink Cadillac', 'Bruce Springsteen', False)
# ('Prove It All Night', 'Bruce Springsteen', False)
# ('Racing in the Streets', 'Bruce Springsteen', False)
# ('Rosalita (Come Out Tonight)', 'Bruce Springsteen', False)
# ("She's The One", 'Bruce Springsteen', False)
# ('Spirit In The Night', 'Bruce Springsteen', False)
# ('Tenth Avenue Freeze-Out', 'Bruce Springsteen', False)
# ('Thunder Road', 'Bruce Springsteen', False)
# ('Cuts Like a Knife', 'Bryan Adams', False)
# ('Heaven', 'Bryan Adams', False)
# ('Run to You', 'Bryan Adams', False)
# ('Somebody', 'Bryan Adams', False)
# ("Summer Of '69", 'Bryan Adams', False)
# ('Sorry', 'Buckcherry', False)
# ("For What It's Worth", 'Buffalo Springfield', True)
# ('Mr. Soul', 'Buffalo Springfield', True)
# ('Rock & Roll Woman', 'Buffalo Springfield', True)
# ('Comedown', 'Bush', False)
# ('Machinehead', 'Bush', False)
# ('Far Behind', 'Candlebox', False)
# ("Goin' up the Country", 'Canned Heat', True)
# ('On the Road Again', 'Canned Heat', True)
# ("IT'S TOO LATE", 'Carole King', False)
# ('Oh Very Young', 'Cat Stevens', True)
# ('WILD WORLD', 'Cat Stevens', False)
# ('In America', 'Charlie Daniels Band', False)
# ('Long Haired Country Boy', 'Charlie Daniels Band', False)
# ('The Devil Went Down To Georgia', 'Charlie Daniels Band', False)
# ('The Legend Of Wooley Swamp', 'Charlie Daniels Band', True)
# ("The South's Gonna Do It Again", 'Charlie Daniels Band', False)
# ('Uneasy Rider', 'Charlie Daniels Band', False)
# ("Ain't That a Shame", 'Cheap Trick', True)
# ('Dream Police', 'Cheap Trick', True)
# ('I Want You to Want Me', 'Cheap Trick', False)
# ("She's Tight", 'Cheap Trick', True)
# ('Surrender', 'Cheap Trick', False)
# ('Take Out The Gunman', 'Chevelle', False)
# ('25 Or 6 To 4', 'Chicago', False)
# ('Beginnings', 'Chicago', True)
# ('Feeling Stronger Every', 'Chicago', False)
# ("I'm a Man", 'Chicago', True)
# ('JUST YOU AND ME', 'Chicago', True)
# ('Make Me Smile', 'Chicago', False)
# ('Questions 67 and 68', 'Chicago', True)
# ('Saturday In the Park', 'Chicago', False)
# ('South California Purples', 'Chicago', True)
# ('JOHNNY B. GOODE', 'Chuck Berry', True)
# ('Coming Home', 'Cinderella', False)
# ("Don't Know What You Got", 'Cinderella', False)
# ('Gypsy Road', 'Cinderella', False)
# ("Nobody's Fool", 'Cinderella', False)
# ('Somebody Save Me', 'Cinderella', False)
# ('Better Off Without You', 'Clarks', True)
# ('Born Too Late', 'Clarks', True)
# ('Cigarette', 'Clarks', True)
# ('Hey You', 'Clarks', True)
# ('Maybe', 'Clarks', True)
# ('Penny On The Floor', 'Clarks', True)
# ('The River', 'Clarks', True)
# ('December', 'Collective Soul', True)
# ('Shine', 'Collective Soul', False)
# ('The World I Know', 'Collective Soul', False)
# ('Hot Rod Lincoln', 'Commander Cody', False)
# ('Monkey Bars', 'Coney Hatch', True)
# ('Mr. Jones', 'Counting Crows', False)
# ('Low', 'Cracker', False)
# ('Badge', 'Cream', True)
# ('Born Under A Bad Sign', 'Cream', True)
# ('Crossroads', 'Cream', True)
# ("I'm So Glad", 'Cream', True)
# ('Sunshine of Your Love', 'Cream', True)
# ('Tales Of Brave Ulysses', 'Cream', True)
# ('White Room', 'Cream', True)
# ('Higher', 'Creed', False)
# ('My Sacrifice', 'Creed', True)
# ('With Arms Wide Open', 'Creed', False)
# ('Bad Moon Rising', 'Creedence Clearwater Revival', True)
# ('Born On the Bayou', 'Creedence Clearwater Revival', True)
# ('Commotion', 'Creedence Clearwater Revival', True)
# ('Down On the Corner', 'Creedence Clearwater Revival', True)
# ('Fortunate Son', 'Creedence Clearwater Revival', False)
# ('Green River', 'Creedence Clearwater Revival', True)
# ('Have You Ever Seen the Rain?', 'Creedence Clearwater Revival', False)
# ('I Heard It Through the Grapevine', 'Creedence Clearwater Revival', True)
# ('Lodi', 'Creedence Clearwater Revival', True)
# ("Lookin' Out My Back Door", 'Creedence Clearwater Revival', False)
# ('Proud Mary', 'Creedence Clearwater Revival', True)
# ('Run Through the Jungle', 'Creedence Clearwater Revival', False)
# ('Suzie Q', 'Creedence Clearwater Revival', True)
# ('Sweet Hitch Hiker', 'Creedence Clearwater Revival', False)
# ('The Midnight Special', 'Creedence Clearwater Revival', True)
# ("Travelin' Band", 'Creedence Clearwater Revival', False)
# ('Up Around the Bend', 'Creedence Clearwater Revival', False)
# ("Who'll Stop the Rain", 'Creedence Clearwater Revival', False)
# ('Fire Woman', 'Crosby, Stills & Nash', True)
# ('Helplessly Hoping', 'Crosby, Stills & Nash', True)
# ('Long Time Gone', 'Crosby, Stills & Nash', True)
# ('Southern Cross', 'Crosby, Stills & Nash', False)
# ('Suite: Judy Blue Eyes', 'Crosby, Stills & Nash', True)
# ('Carry On', 'Crosby, Stills, Nash & Young', False)
# ('Ohio', 'Crosby, Stills, Nash & Young', False)
# ('Woodstock', 'Crosby, Stills, Nash & Young', False)
# ('(I Just) Died in Your Arms', 'Cutting Crew', False)
# ('High Enough', 'Damn Yankees', False)
# ('I HEAR YOU KNOCKING', 'Dave Edmunds', False)
# ('Headkeeper', 'Dave Mason', True)
# ('Only You Know And I Know', 'Dave Mason', True)
# ('We Just Disagree', 'Dave Mason', False)
# ('Welcome To The Boomtown', 'David & David', False)
# ('Changes', 'David Bowie', False)
# ('China Girl', 'David Bowie', False)
# ('Diamond Dogs', 'David Bowie', False)
# ('Fame', 'David Bowie', False)
# ('Fashion', 'David Bowie', False)
# ('Friday on My Mind', 'David Bowie', True)
# ('Golden Years', 'David Bowie', False)
# ('Heroes', 'David Bowie', False)
# ('Jean Genie', 'David Bowie', True)
# ("Let's Dance", 'David Bowie', False)
# ('Modern Love', 'David Bowie', False)
# ('Panic in Detroit', 'David Bowie', True)
# ('Rebel Rebel', 'David Bowie', False)
# ('Space Oddity', 'David Bowie', True)
# ('Starman', 'David Bowie', False)
# ('Stay', 'David Bowie', True)
# ('Suffragette City', 'David Bowie', False)
# ('Young Americans', 'David Bowie', False)
# ('Ziggy Stardust', 'David Bowie', False)
# ('Rock On', 'David Essex', False)
# ("There's No Way Out Of Here", 'David Essex', True)
# ("There's No Way Out Of Here", 'David Gilmour', True)
# ('Frenchette', 'David Johansen', True)
# ('California Girls', 'David Lee Roth', True)
# ("Just A Gigolo / I Ain't Got Nobody", 'David Lee Roth', False)
# ('Yankee Rose', 'David Lee Roth', False)
# ('Burn', 'Deep Purple', False)
# ('Child In Time', 'Deep Purple', False)
# ('Highway Star', 'Deep Purple', False)
# ('Hush', 'Deep Purple', True)
# ('Kentucky Woman', 'Deep Purple', True)
# ('Knocking At Your Backdoo', 'Deep Purple', False)
# ('Lazy', 'Deep Purple', False)
# ('Perfect Strangers', 'Deep Purple', True)
# ('Smoke On The Water', 'Deep Purple', False)
# ("Space Truckin'", 'Deep Purple', True)
# ('Woman From Tokyo', 'Deep Purple', True)
# ('Animal', 'Def Leppard', False)
# ('Armageddon It', 'Def Leppard', False)
# ("Bringin' On The Heartbreak", 'Def Leppard', True)
# ("Foolin'", 'Def Leppard', True)
# ('Hysteria', 'Def Leppard', False)
# ('Love Bites', 'Def Leppard', False)
# ('On Through The Night', 'Def Leppard', True)
# ('Photograph', 'Def Leppard', False)
# ('Pour Some Sugar On Me', 'Def Leppard', False)
# ('Rock of Ages', 'Def Leppard', False)
# ('Rock Rock', 'Def Leppard', True)
# ('Rocket', 'Def Leppard', False)
# ('Too Late for Love', 'Def Leppard', True)
# ('Enjoy the Silence', 'Depeche Mode', False)
# ('Bell Bottom Blues', 'Derek & The Dominos', False)
# ('Have You Ever Loved a Woman', 'Derek & The Dominos', True)
# ('Layla', 'Derek & The Dominos', False)
# ('Recognition', 'Detective', True)
# ('ANGELOS', 'Dick Siegel', True)
# ('Holy Diver', 'Dio', True)
# ('Rainbow In the Dark', 'Dio', True)
# ('The Last In Line', 'Dio', True)
# ('Brothers In Arms', 'Dire Straits', False)
# ('Down To The Waterline', 'Dire Straits', False)
# ('Expresso Love', 'Dire Straits', False)
# ('Industrial Disease', 'Dire Straits', False)
# ('Lady Writer', 'Dire Straits', False)
# ('Money for Nothing', 'Dire Straits', False)
# ('Romeo And Juliet', 'Dire Straits', False)
# ('So Far Away', 'Dire Straits', False)
# ('Solid Rock', 'Dire Straits', True)
# ('Sultans of Swing', 'Dire Straits', False)
# ('Walk of Life', 'Dire Straits', False)
# ('Counting Blue Cars', 'Dishwalla', False)
# ('Drift Away', 'Dobie Gray', False)
# ('Alone Again', 'Dokken', True)
# ('In My Dreams', 'Dokken', True)
# ('Into The Fire', 'Dokken', True)
# ('Heavy Metal', 'Don Felder', False)
# ('All She Wants to Do Is Dance', 'Don Henley', False)
# ('Dirty Laundry', 'Don Henley', False)
# ('Sunset Grill', 'Don Henley', False)
# ('The Boys Of Summer', 'Don Henley', False)
# ('The Heart of the Matter', 'Don Henley', False)
# ('The Last Worthless Evening', 'Don Henley', True)
# ('American Pie', 'Don McLean', False)
# ('Ah! Leah!', 'Donnie Iris', False)
# ('Love Is Like A Rock', 'Donnie Iris', False)
# ('Season of the Witch', 'Donovan', True)
# ('Sunshine Superman', 'Donovan', True)
# ('COVER OF THE ROLLING STONE', 'Dr. Hook & the Medicine Show', True)
# ('Right Place Wrong Time', 'Dr. John', False)
# ('Anything, Anything', 'Dramarama', True)
# ('Hey, Hey (What Can I Do?)', 'Led Zeppelin', False)
# ('Rio', 'Duran Duran', False)
# ('Already Gone', 'Eagles', False)
# ('Desperado', 'Eagles', False)
# ('Heartache Tonight', 'Eagles', False)
# ('Hotel California', 'Eagles', False)
# ("I Can't Tell You Why", 'Eagles', False)
# ('In The City', 'Eagles', False)
# ('Life in the Fast Lane', 'Eagles', False)
# ("Lyin' Eyes", 'Eagles', False)
# ('New Kid In Town', 'Eagles', False)
# ('One of These Nights', 'Eagles', False)
# ('Peaceful Easy Feeling', 'Eagles', False)
# ('Seven Bridges Road', 'Eagles', False)
# ('Take It Easy', 'Eagles', False)
# ('Take It to the Limit', 'Eagles', False)
# ('Tequila Sunrise', 'Eagles', False)
# ('The Best of My Love', 'Eagles', False)
# ('The Long Run', 'Eagles', False)
# ('Those Shoes', 'Eagles', False)
# ('Victim of Love', 'Eagles', False)
# ('Witchy Woman', 'Eagles', False)
# ('Baby Hold On', 'Eddie Money', False)
# ('Gimme Some Water', 'Eddie Money', True)
# ("Shakin'", 'Eddie Money', True)
# ('Take Me Home Tonight', 'Eddie Money', False)
# ("Think I'm In Love", 'Eddie Money', True)
# ('Two Tickets To Paradise', 'Eddie Money', True)
# ('Frankenstein', 'Edgar Winter Group', True)
# ('Free Ride', 'Edgar Winter Group', False)
# ('WAR', 'Edwin Starr', False)
# ("CAN'T GET IT OUT OF MY HEAD", 'Electric Light Orchestra', False)
# ('Do Ya', 'Electric Light Orchestra', True)
# ("Don't Bring Me Down", 'Electric Light Orchestra', False)
# ('Evil Woman', 'Electric Light Orchestra', False)
# ('Fire On High', 'Electric Light Orchestra', False)
# ("Livin' Thing", 'Electric Light Orchestra', False)
# ('Roll Over Beethoven', 'Electric Light Orchestra', True)
# ('Strange Magic', 'Electric Light Orchestra', False)
# ("Sweet Talkin' Woman", 'Electric Light Orchestra', False)
# ('Telephone Line', 'Electric Light Orchestra', True)
# ('Turn To Stone', 'Electric Light Orchestra', False)
# ('All The Girls Love Alice', 'Elton John', False)
# ('Bennie And The Jets', 'Elton John', False)
# ('Candle in the Wind', 'Elton John', False)
# ('Captain Fantastic', 'Elton John', False)
# ('Crocodile Rock', 'Elton John', False)
# ('DANIEL', 'Elton John', False)
# ("Don't Let The Sun Go Down On Me", 'Elton John', False)
# ('Funeral for a Friend (Love Lies Bleeding)', 'Elton John', False)
# ('Goodbye Yellow Brick Road', 'Elton John', False)
# ('Harmony', 'Elton John', False)
# ('Honky Cat', 'Elton John', False)
# ('Levon', 'Elton John', True)
# ('Madman Across The Water', 'Elton John', False)
# ('Rocket Man', 'Elton John', False)
# ("Saturday Night's Alright for Fighting", 'Elton John', False)
# ('Someone Saved My Life Tonight', 'Elton John', False)
# ('Take Me to the Pilot', 'Elton John', True)
# ('Teacher I Need You', 'Elton John', True)
# ('THE BITCH IS BACK', 'Elton John', False)
# ('Tiny Dancer', 'Elton John', False)
# ('Where To Now St. Peter', 'Elton John', False)
# ('Your Song', 'Elton John', False)
# ('Fooled around and Fell in Love', 'Elvin Bishop', False)
# ('Alison', 'Elvis Costello', False)
# ('Pump It Up', 'Elvis Costello', False)
# ('Veronica', 'Elvis Costello', False)
# ('From the Beginning', 'Emerson, Lake & Palmer', False)
# ('Hoedown', 'Emerson, Lake & Palmer', True)
# ('Karn Evil 9', 'Emerson, Lake & Palmer', False)
# ('Lucky Man', 'Emerson, Lake & Palmer', False)
# ('Still You Turn Me On', 'Emerson, Lake & Palmer', False)
# ('After Midnight', 'Eric Clapton', False)
# ('Bad Love', 'Eric Clapton', False)
# ('Call Me the Breeze', 'Eric Clapton', True)
# ('Cocaine', 'Eric Clapton', False)
# ("Don't Think Twice, It's Alright", 'Eric Clapton', True)
# ('Forever Man', 'Eric Clapton', False)
# ("I Can't Stand It", 'Eric Clapton', False)
# ('I Shot The Sheriff', 'Eric Clapton', False)
# ("I've Got a Rock 'N' Roll Heart", 'Eric Clapton', True)
# ("It's In The Way That You Use It", 'Eric Clapton', False)
# ("Knockin' On Heaven's Door", 'Eric Clapton', True)
# ('Lay Down Sally', 'Eric Clapton', False)
# ('Layla', 'Eric Clapton', True)
# ('Let It Grow', 'Eric Clapton', False)
# ('Let It Rain', 'Eric Clapton', False)
# ('Pretending', 'Eric Clapton', False)
# ("She's Waiting", 'Eric Clapton', False)
# ('Tears In Heaven', 'Eric Clapton', True)
# ('The Core', 'Eric Clapton', False)
# ('Willie and the Hand Jive', 'Eric Clapton', True)
# ('Wonderful Tonight', 'Eric Clapton', False)
# ('Cliffs Of Dover', 'Eric Johnson', False)
# ('The Final Countdown', 'Europe', False)
# ('Sweet Dreams (Are Made of This)', 'Eurythmics', False)
# ('Inside Out', 'Eve 6', True)
# ('Santa Monica', 'Everclear', False)
# ('The Boys Are Back In Town', 'Everclear', True)
# ("What It's Like", 'Everlast', False)
# ('More Than Words', 'Extreme', False)
# ("Mutha (Don't Wanna Go To School Today)", 'Extreme', True)
# ('Ooh La La', 'Faces', False)
# ('Stay With Me', 'Faces', False)
# ('Epic', 'Faith No More', False)
# ('House Of Pain', 'Faster Pussycat', False)
# ('All The Kings Horses', 'Firm', True)
# ('Signs', 'Five Man Electrical Band', False)
# ('Blue Letter', 'Fleetwood Mac', True)
# ("Don't Stop", 'Fleetwood Mac', False)
# ('Dreams', 'Fleetwood Mac', False)
# ('Go Your Own Way', 'Fleetwood Mac', False)
# ('Gold Dust Woman', 'Fleetwood Mac', False)
# ('Gypsy', 'Fleetwood Mac', False)
# ('Hold Me', 'Fleetwood Mac', False)
# ('Hypnotized', 'Fleetwood Mac', False)
# ("I Don't Want To Know", 'Fleetwood Mac', False)
# ("I'm So Afraid", 'Fleetwood Mac', True)
# ('Landslide', 'Fleetwood Mac', False)
# ('Little Lies', 'Fleetwood Mac', False)
# ('Monday Morning', 'Fleetwood Mac', False)
# ('Never Going Back Again', 'Fleetwood Mac', False)
# ('Oh Well', 'Fleetwood Mac', True)
# ('Rhiannon', 'Fleetwood Mac', False)
# ('Sara', 'Fleetwood Mac', False)
# ('Say You Love Me', 'Fleetwood Mac', True)
# ('Second Hand News', 'Fleetwood Mac', False)
# ('Sentimental Lady', 'Fleetwood Mac', True)
# ('The Chain', 'Fleetwood Mac', False)
# ('Tusk', 'Fleetwood Mac', False)
# ('World Turning', 'Fleetwood Mac', True)
# ('You Make Loving Fun', 'Fleetwood Mac', False)
# ('Hocus Pocus', 'Focus', False)
# ('Dreamer', 'Foghat', True)
# ('Fool For The City', 'Foghat', False)
# ('I Just Want To Make Love To You', 'Foghat', True)
# ('Slow Ride', 'Foghat', False)
# ('All My Life', 'Foo Fighters', False)
# ('Baker Street', 'Foo Fighters', True)
# ('Best of You', 'Foo Fighters', False)
# ('Everlong', 'Foo Fighters', False)
# ('Learn To Fly', 'Foo Fighters', False)
# ('Monkey Wrench', 'Foo Fighters', False)
# ('My Hero', 'Foo Fighters', False)
# ('The Pretender', 'Foo Fighters', False)
# ('These Days', 'Foo Fighters', False)
# ('Times Like These', 'Foo Fighters', False)
# ('Blue Morning, Blue Day', 'Foreigner', True)
# ('Cold As Ice', 'Foreigner', False)
# ('Dirty White Boy', 'Foreigner', False)
# ('Double Vision', 'Foreigner', False)
# ('Feels Like the First Time', 'Foreigner', False)
# ('Head Games', 'Foreigner', True)
# ('Hot Blooded', 'Foreigner', False)
# ('I Want to Know What Love Is', 'Foreigner', False)
# ('Juke Box Hero', 'Foreigner', False)
# ('Long, Long Way From Home', 'Foreigner', True)
# ('Love Has Taken Its Toll', 'Foreigner', True)
# ('Starrider', 'Foreigner', True)
# ('That Was Yesterday', 'Foreigner', False)
# ('Urgent', 'Foreigner', False)
# ('Waiting for a Girl Like You', 'Foreigner', False)
# ('Women', 'Foreigner', True)
# ("Joe's Garage", 'Frank Zappa', False)
# ('Peaches En Regalia', 'Frank Zappa', True)
# ('All Right Now', 'Free', False)
# ('Hemorrhage', 'Free', True)
# ('Wishing Well', 'Free', False)
# ('Maggot Brain', 'Funkadelic', False)
# ('CARS', 'Gary Numan', False)
# ('Dream Weaver', 'Gary Wright', False)
# ('Love Is Alive', 'Gary Wright', True)
# ('A Trick of the Tail', 'Genesis', False)
# ('Abacab', 'Genesis', False)
# ('Behind The Lines', 'Genesis', True)
# ('Carpet Crawlers', 'Genesis', True)
# ('Follow You Follow Me', 'Genesis', False)
# ('Home by the Sea/Second Home by the Sea', 'Genesis', False)
# ('Just A Job To Do', 'Genesis', True)
# ('Land Of Confusion', 'Genesis', False)
# ('Mama', 'Genesis', False)
# ('Man On The Corner', 'Genesis', False)
# ('Misunderstanding', 'Genesis', False)
# ('No Reply At All', 'Genesis', False)
# ("That's All", 'Genesis', False)
# ('The Lamb Lies Down On Broadway', 'Genesis', False)
# ('Tonight Tonight (live)', 'Genesis', False)
# ('Turn It On Again', 'Genesis', False)
# ('Give Me Love', 'George Harrison', False)
# ('GOT MY MIND SET ON YOU', 'George Harrison', False)
# ('My Sweet Lord', 'George Harrison', False)
# ('Bad to the Bone', 'George Thorogood', False)
# ('Delaware Slide', 'George Thorogood', True)
# ('Get A Haircut', 'George Thorogood', True)
# ('I Drink Alone', 'George Thorogood', False)
# ("It Wasn't Me", 'George Thorogood', True)
# ('Move It On Over', 'George Thorogood', True)
# ('One Bourbon, One Scotch, One Beer', 'George Thorogood', True)
# ('Who Do You Love', 'George Thorogood', True)
# ('Keep Your Hands To Yourself', 'Georgia Satellites', False)
# ('Baker Street', 'Gerry Rafferty', False)
# ('Right Down the Line', 'Gerry Rafferty', False)
# ('Found Out About You', 'Gin Blossoms', False)
# ('Hey Jealousy', 'Gin Blossoms', False)
# ("Smuggler's Blues", 'Glenn Frey', False)
# ('You Belong to the City', 'Glenn Frey', False)
# ('Marakesh Express', 'Gold Star Ballroom Orchestra', True)
# ('Are You Receiving Me', 'Golden Earring', False)
# ('Radar Love', 'Golden Earring', False)
# ('Twilight Zone', 'Golden Earring', False)
# ('Sundown', 'Gordon Lightfoot', False)
# ('Soulshine', "Gov't Mule", True)
# ('Bad Time', 'Grand Funk Railroad', False)
# ("Closer To Home (I'm Your Captain)", 'Grand Funk Railroad', False)
# ('Loco-Motion', 'Grand Funk Railroad', False)
# ("Shinin' On", 'Grand Funk Railroad', False)
# ('Some Kind of Wonderful', 'Grand Funk Railroad', False)
# ("We're an American Band", 'Grand Funk Railroad', False)
# ('Alabama Getaway', 'Grateful Dead', True)
# ('Black-Throated Wind', 'Grateful Dead', True)
# ('Casey Jones', 'Grateful Dead', False)
# ('CHINA TOWN SHUFFLE ', 'Grateful Dead', True)
# ('Friend Of The Devil', 'Grateful Dead', False)
# ('Hell in a Bucket', 'Grateful Dead', True)
# ('Loser', 'Grateful Dead', True)
# ('Me and Bobby McGee', 'Grateful Dead', True)
# ('NOT FADEAWAY/GOING /AWAY', 'Grateful Dead', True)
# ('Scarlet Begonias', 'Grateful Dead', True)
# ('Shakedown Street', 'Grateful Dead', True)
# ('Sugar Magnolia', 'Grateful Dead', False)
# ('Touch of Grey', 'Grateful Dead', False)
# ("Truckin'", 'Grateful Dead', False)
# ('Turn On Your Lovelight', 'Grateful Dead', True)
# ('U.S. Blues', 'Grateful Dead', True)
# ("Uncle John's Band", 'Grateful Dead', True)
# ('Mista Bone', 'Great White', True)
# ('Once Bitten, Twice Shy', 'Great White', False)
# ('Rock Me', 'Great White', True)
# ("Rollin' Stoned", 'Great White', True)
# ('Save Your Love', 'Great White', True)
# ('Basket Case', 'Green Day', False)
# ('Boulevard Of Broken Dreams', 'Green Day', False)
# ('Brain Stew/Jaded', 'Green Day', False)
# ('Good Riddance (Time Of Your Life)', 'Green Day', False)
# ('Holiday (Live)', 'Green Day', False)
# ('Holiday / Boulevard of Broken Dreams', 'Green Day', False)
# ('Longview', 'Green Day', False)
# ('When I Come Around', 'Green Day', False)
# ('The Break Up Song', 'Greg Kihn Band', False)
# ("I'm No Angel", 'Gregg Allman', False)
# ('Midnight Rider', 'Gregg Allman', False)
# ('American Woman', 'Guess Who', False)
# ('Friends Of Mine', 'Guess Who', True)
# ('No Sugar Tonight / New Mother Nature', 'Guess Who', False)
# ('No Time', 'Guess Who', True)
# ('THESE EYES', 'Guess Who', True)
# ('Civil War', "Guns N' Roses", False)
# ("Don't Cry", "Guns N' Roses", True)
# ("Knockin' On Heaven's Door", "Guns N' Roses", True)
# ('Live and Let Die', "Guns N' Roses", True)
# ('Mr. Brownstone', "Guns N' Roses", False)
# ('My Michelle', "Guns N' Roses", False)
# ('November Rain', "Guns N' Roses", False)
# ('Paradise City', "Guns N' Roses", False)
# ('Patience', "Guns N' Roses", False)
# ("Sweet Child O' Mine", "Guns N' Roses", False)
# ('Used To Love Her', "Guns N' Roses", False)
# ('Welcome to the Jungle', "Guns N' Roses", False)
# ('You Could Be Mine', "Guns N' Roses", True)
# ('AS FAR AS YOU CAN SEE (AS MU', 'Gypsy', True)
# ('Axel F Theme', 'Harold Faltermeyer', False)
# ("Cat's In The Cradle", 'Harry Chapin', False)
# ('W*O*L*D*', 'Harry Chapin', False)
# ('Jump into the Fire', 'Harry Nilsson', True)
# ('Never Been Any Reason', 'Head East', False)
# ('All I Wanna Do Is Make Love to You', 'Heart', True)
# ('Alone', 'Heart', False)
# ('Barracuda', 'Heart', False)
# ('Bebe le Strange', 'Heart', True)
# ('Crazy On You', 'Heart', False)
# ('Dog & Butterfly', 'Heart', True)
# ('Dreamboat Annie', 'Heart', False)
# ('Even It Up', 'Heart', True)
# ('Heartless', 'Heart', True)
# ('How Can I Refuse', 'Heart', False)
# ('If Looks Could Kill', 'Heart', True)
# ('Kick It Out', 'Heart', True)
# ('Little Queen', 'Heart', True)
# ('Love Alive', 'Heart', True)
# ('Magic Man', 'Heart', False)
# ('Mistral Wind', 'Heart', True)
# ('Never', 'Heart', True)
# ("Nothin' at All", 'Heart', True)
# ('Rock And Roll', 'Heart', True)
# ('Stairway To Heaven', 'Heart', True)
# ('Straight On', 'Heart', False)
# ('Tell It Like It Is', 'Heart', True)
# ('What About Love?', 'Heart', True)
# ('Who Will You Run To', 'Heart', True)
# ('House Of Living', 'Heartsfield', True)
# ('Sangre Por Sangre', 'HellYeah', True)
# ('Grey Ghost', 'Henry Paul Band', False)
# ('Long Cool Woman', 'Hollies', False)
# ('New Girl Now', 'Honeymoon Suite', True)
# ('ALL YOU ZOMBIES', 'Hooters', False)
# ('AND WE DANCED', 'Hooters', False)
# ('I Want A New Drug', 'Huey Lewis & The News', False)
# ('30 Days In the Hole', 'Humble Pie', False)
# ('Lust for Life', 'Iggy Pop', False)
# ('The Passenger', 'Iggy Pop', False)
# ('Radioactive', 'Imagine Dragons', False)
# ('Devil Inside', 'INXS', False)
# ('Need You Tonight', 'INXS', False)
# ('New Sensation', 'INXS', True)
# ('What You Need', 'INXS', False)
# ('In A Gadda Da Vida', 'Iron Butterfly', True)
# ('Flight Of Icarus', 'Iron Maiden', False)
# ('Run To The Hills', 'Iron Maiden', False)
# ('The Number Of The Beast', 'Iron Maiden', False)
# ('The Trooper', 'Iron Maiden', False)
# ('Wasted Years', 'Iron Maiden', False)
# ('Centerfold', 'J. Geils Band', False)
# ('Freeze-frame', 'J. Geils Band', False)
# ('Give It To Me', 'J. Geils Band', False)
# ('Houseparty', 'J. Geils Band', True)
# ('Looking For A Love', 'J. Geils Band', True)
# ('Love Stinks', 'J. Geils Band', True)
# ('Must of Got Lost', 'J. Geils Band', True)
# ('Night Time', 'J. Geils Band', True)
# ('Whammer Jammer', 'J. Geils Band', True)
# ('Boulevard', 'Jackson Browne', True)
# ('Doctor My Eyes', 'Jackson Browne', False)
# ('Load Out/Stay', 'Jackson Browne', False)
# ('Redneck Friend', 'Jackson Browne', False)
# ('Running On Empty', 'Jackson Browne', False)
# ("Somebody's Baby", 'Jackson Browne', False)
# ('Take It Easy', 'Jackson Browne', True)
# ('The Load-out/stay', 'Jackson Browne', False)
# ('The Road and the Sky', 'Jackson Browne', False)
# ('Funk #49', 'James Gang', False)
# ('Walk Away', 'James Gang', True)
# ("YOU'VE GOT A FRIEND", 'JAMES TAYLOR', False)
# ('Been Caught Stealing', "Jane's Addiction", False)
# ('Jane Says', "Jane's Addiction", False)
# ('Get It While You Can', 'Janis Joplin', False)
# ('Me and Bobby McGee', 'Janis Joplin', False)
# ('Move Over', 'Janis Joplin', False)
# ('Piece of My Heart', 'Janis Joplin', True)
# ('Summertime', 'Janis Joplin', True)
# ('Shakedown Cruise', 'Jay Ferguson', True)
# ('Thunder Island', 'Jay Ferguson', False)
# ('Freeway Jam', 'Jeff Beck', False)
# ('Rice Pudding', 'Jeff Beck', True)
# ('Somebody to Love', 'Jefferson Airplane', True)
# ('White Rabbit', 'Jefferson Airplane', True)
# ('Find Your Way Back', 'Jefferson Starship', True)
# ('Jane', 'Jefferson Starship', False)
# ('Ride the Tiger', 'Jefferson Starship', True)
# ('We Built This City', 'Jefferson Starship', False)
# ('Right Here Right Now', 'Jesus Jones', False)
# ('Are You Gonna Be My Girl', 'Jet', False)
# ('Cold Hard Bitch', 'Jet', False)
# ('Aqualung', 'Jethro Tull', False)
# ('Bungle In The Jungle', 'Jethro Tull', False)
# ('Cross-eyed Mary', 'Jethro Tull', False)
# ('Hymn 43', 'Jethro Tull', True)
# ('Living In The Past', 'Jethro Tull', True)
# ('Locomotive Breath', 'Jethro Tull', False)
# ('Nothing Is Easy', 'Jethro Tull', True)
# ('Teacher', 'Jethro Tull', False)
# ('Thick As A Brick', 'Jethro Tull', True)
# ("Too Old To Rock 'n' Roll", 'Jethro Tull', True)
# ('TIME IN A BOTTLE', 'Jim Croce', False)
# ('All Along the Watchtower', 'Jimi Hendrix', True)
# ('Angel', 'Jimi Hendrix', False)
# ('Are You Experienced?', 'Jimi Hendrix', True)
# ('Crosstown Traffic', 'Jimi Hendrix', True)
# ('Dolly Dagger', 'Jimi Hendrix', False)
# ('Fire', 'Jimi Hendrix', True)
# ('Foxey Lady', 'Jimi Hendrix', True)
# ('Hey Joe', 'Jimi Hendrix', True)
# ('If 6 Was 9', 'Jimi Hendrix', True)
# ('Like a Rolling Stone', 'Jimi Hendrix', True)
# ('Little Wing', 'Jimi Hendrix', True)
# ('Manic Depression', 'Jimi Hendrix', True)
# ('Purple Haze', 'Jimi Hendrix', True)
# ('Red House', 'Jimi Hendrix', True)
# ('Stone Free', 'Jimi Hendrix', True)
# ('The Wind Cries Mary', 'Jimi Hendrix', True)
# ('Third Stone From The Sun', 'Jimi Hendrix', True)
# ('Voodoo Child (Slight Return)', 'Jimi Hendrix', True)
# ('Margaritaville', 'Jimmy Buffett', False)
# ('Son of a Son of a Sailor', 'Jimmy Buffett', False)
# ("Why Don't We Get Drunk", 'Jimmy Buffett', False)
# ('Bad Reputation', 'Joan Jett', False)
# ('Crimson And Clover', 'Joan Jett', True)
# ('I Hate Myself For Loving You', 'Joan Jett', False)
# ("I Love Rock 'n Roll", 'Joan Jett', False)
# ('Cry Me a River', 'Joe Cocker', True)
# ("Feelin' Alright", 'Joe Cocker', True)
# ('The Letter', 'Joe Cocker', True)
# ('With A Little Help From My Friends', 'Joe Cocker', True)
# ('You Can Leave Your Hat On (Live)', 'Joe Cocker', True)
# ('Is She Really Going Out With Him?', 'Joe Jackson', False)
# ('Always With Me, Always With You', 'Joe Satriani', True)
# ('Summer Song', 'Joe Satriani', True)
# ('A Life Of Illusion', 'Joe Walsh', False)
# ('All Night Long', 'Joe Walsh', False)
# ('Analog Man', 'Joe Walsh', False)
# ('Funk #49', 'Joe Walsh', False)
# ('In the City', 'Joe Walsh', False)
# ("Life's Been Good", 'Joe Walsh', True)
# ('Ordinary Average Guy', 'Joe Walsh', False)
# ('Rocky Mountain Way', 'Joe Walsh', False)
# ('The Confessor', 'Joe Walsh', True)
# ('Turn To Stone', 'Joe Walsh', True)
# ('On the Dark Side', 'John Cafferty', False)
# ('Centerfield', 'John Fogerty', False)
# ('The Old Man Down The Road', 'John Fogerty', False)
# ('#9 Dream', 'John Lennon', False)
# ('Imagine', 'John Lennon', False)
# ('Instant Karma', 'John Lennon', False)
# ('Mind Games', 'John Lennon', True)
# ('Watching the Wheels', 'John Lennon', False)
# ('Woman', 'John Lennon', False)
# ('Again Tonight', 'John Mellencamp', True)
# ("Ain't Even Done With the Night", 'John Mellencamp', True)
# ('Authority Song', 'John Mellencamp', False)
# ('Check It Out', 'John Mellencamp', True)
# ('Cherry Bomb', 'John Mellencamp', True)
# ("Crumblin' Down", 'John Mellencamp', False)
# ('Hurts So Good', 'John Mellencamp', False)
# ('I Need A Lover', 'John Mellencamp', False)
# ('Jack & Diane', 'John Mellencamp', False)
# ("Lonely Ol' Night", 'John Mellencamp', False)
# ('Paper in Fire', 'John Mellencamp', False)
# ('Pink Houses', 'John Mellencamp', False)
# ('R.O.C.K. In the U.S.A.', 'John Mellencamp', False)
# ('Rain On The Scarecrow', 'John Mellencamp', False)
# ('Small Town', 'John Mellencamp', False)
# ('What If I Came Knocking', 'John Mellencamp', True)
# ('Illegal Smile', 'John Prine', True)
# ('I CAN SEE CLEARLY NOW', 'Johnny Nash', False)
# ('Brickyard Road', 'Johnny Van Zant', False)
# ('Shanty', 'Jonathan Edwards', True)
# ('Roadrunner', 'Jonathan Richman', False)
# ('Any Way You Want It', 'Journey', False)
# ('City of the Angels', 'Journey', True)
# ("Don't Stop Believin'", 'Journey', False)
# ('Escape', 'Journey', True)
# ('Faithfully', 'Journey', False)
# ('Feeling That Way', 'Journey', False)
# ('Just the Same Way', 'Journey', True)
# ('Lights', 'Journey', False)
# ('Look Into The Future', 'Journey', True)
# ("Lovin', Touchin' Squeezin'", 'Journey', False)
# ('Only the Young', 'Journey', False)
# ('Open Arms', 'Journey', False)
# ('Send Her My Love', 'Journey', False)
# ('Separate Ways (Worlds Apart)', 'Journey', False)
# ('Stone In Love', 'Journey', True)
# ('Wheel in the Sky', 'Journey', False)
# ("Who's Crying Now", 'Journey', False)
# ('Breaking The Law', 'Judas Priest', False)
# ('Diamonds And Rust', 'Judas Priest', True)
# ('Electric Eye', 'Judas Priest', False)
# ('Heading Out To The Highway', 'Judas Priest', True)
# ("Hot Rockin'", 'Judas Priest', True)
# ('Living After Midnight', 'Judas Priest', False)
# ('The Ripper', 'Judas Priest', False)
# ('Turbo Lover', 'Judas Priest', True)
# ("You've Got Another Thing Comin'", 'Judas Priest', True)
# ('Simple Man', 'Junkyard', True)
# ('Carry On Wayward Son', 'Kansas', False)
# ('Dust In The Wind', 'Kansas', False)
# ('Play the Game Tonight', 'Kansas', False)
# ('Point of Know Return', 'Kansas', False)
# ("I'm Alright", 'Kenny Loggins', False)
# ('Just Dropped In', 'Kenny Loggins', True)
# ('Blue On Black', 'Kenny Wayne Shepherd', True)
# ('Somehow, Somewhere, Someway', 'Kenny Wayne Shepherd', True)
# ('All Summer Long', 'Kid Rock', False)
# ('Cowboy', 'Kid Rock', False)
# ("Let's Ride", 'Kid Rock', False)
# ('If I Say', 'Kingofthehill', True)
# ('Sex On Fire', 'Kings of Leon', False)
# ('Use Somebody', 'Kings of Leon', False)
# ('Beth', 'Kiss', False)
# ('Calling Dr. Love', 'Kiss', False)
# ('Christeen Sixteen', 'Kiss', True)
# ('Cold Gin', 'Kiss', False)
# ('Detroit Rock City', 'Kiss', False)
# ("Heaven's On Fire", 'Kiss', True)
# ('Lick It Up', 'Kiss', False)
# ('Rock And Roll All Nite', 'Kiss', False)
# ('Shout It out Loud', 'Kiss', True)
# ('Strutter', 'Kiss', False)
# ('Tears Are Falling', 'Kiss', True)
# ('Long Stick Goes Boom', 'Krokus', True)
# ('Screaming In The Night', 'Krokus', True)
# ('Stayed Awake All Night', 'Krokus', True)
# ('Sex Action', 'L.A. Guns', True)
# ('Key To The Rhyme', 'Lake', True)
# ('All My Love', 'Led Zeppelin', False)
# ("Babe I'm Gonna Leave You", 'Led Zeppelin', True)
# ('Black Dog', 'Led Zeppelin', False)
# ('Black Mountain Side', 'Led Zeppelin', True)
# ("Bonzo's Montreaux", 'Led Zeppelin', False)
# ('Boogie With Stu', 'Led Zeppelin', False)
# ('Bring It On Home', 'Led Zeppelin', True)
# ('Bron-y-aur Stomp', 'Led Zeppelin', False)
# ('Celebration Day', 'Led Zeppelin', False)
# ('Communication Breakdown', 'Led Zeppelin', True)
# ('Custard Pie', 'Led Zeppelin', False)
# ("D'Yer Mak'er", 'Led Zeppelin', False)
# ('Dancing Days', 'Led Zeppelin', False)
# ('Darlene', 'Led Zeppelin', False)
# ('Dazed and Confused', 'Led Zeppelin', True)
# ('Down By The Seaside', 'Led Zeppelin', False)
# ('Fool In the Rain', 'Led Zeppelin', False)
# ('For Your Life', 'Led Zeppelin', False)
# ('Four Sticks', 'Led Zeppelin', False)
# ('Friends', 'Led Zeppelin', False)
# ('Gallows Pole', 'Led Zeppelin', False)
# ('Going to California', 'Led Zeppelin', False)
# ('Good Times Bad Times', 'Led Zeppelin', True)
# ('Hats Off To {roy} Harper', 'Led Zeppelin', False)
# ("Heartbreaker/living Loving Maid {she's Just A Woman}", 'Led Zeppelin', True)
# ('Hey Hey What Can I Do', 'Led Zeppelin', False)
# ('Hot Dog', 'Led Zeppelin', False)
# ('Houses of the Holy', 'Led Zeppelin', False)
# ('How Many More Times', 'Led Zeppelin', True)
# ("I Can't Quit You Baby", 'Led Zeppelin', True)
# ('Immigrant Song', 'Led Zeppelin', False)
# ('In My Time of Dying', 'Led Zeppelin', False)
# ('In the Evening', 'Led Zeppelin', False)
# ('In the Light', 'Led Zeppelin', False)
# ('Kashmir', 'Led Zeppelin', False)
# ("Living Loving Maid (She's Just a Woman)", 'Led Zeppelin', True)
# ('Misty Mountain Hop', 'Led Zeppelin', False)
# ('Moby Dick', 'Led Zeppelin', True)
# ('NIGHT FLIGHT', 'Led Zeppelin', False)
# ('No Quarter', 'Led Zeppelin', False)
# ("Nobody's Fault But Mine", 'Led Zeppelin', True)
# ('Out On The Tiles', 'Led Zeppelin', False)
# ('Over the Hills and Far Away', 'Led Zeppelin', False)
# ('Ramble On', 'Led Zeppelin', True)
# ('Rock and Roll', 'Led Zeppelin', False)
# ('Royal Orleans', 'Led Zeppelin', False)
# ("Since I've Been Loving You", 'Led Zeppelin', False)
# ('South Bound Saurez', 'Led Zeppelin', False)
# ('Stairway to Heaven', 'Led Zeppelin', False)
# ('TANGERINE', 'Led Zeppelin', False)
# ('Ten Years Gone', 'Led Zeppelin', False)
# ('Thank You', 'Led Zeppelin', True)
# ("That's the Way", 'Led Zeppelin', False)
# ('The Battle Of Evermore', 'Led Zeppelin', False)
# ('The Crunge', 'Led Zeppelin', False)
# ('The Lemon Song', 'Led Zeppelin', True)
# ('The Ocean', 'Led Zeppelin', False)
# ('The Rain Song', 'Led Zeppelin', False)
# ('The Rover', 'Led Zeppelin', False)
# ('The Song Remains the Same', 'Led Zeppelin', False)
# ('THE WANTON SONG', 'Led Zeppelin', False)
# ('Trampled Under Foot', 'Led Zeppelin', False)
# ('Traveling Riverside Blues', 'Led Zeppelin', False)
# ('What Is and What Should Never Be', 'Led Zeppelin', True)
# ('When The Levee Breaks', 'Led Zeppelin', False)
# ('Whole Lotta Love', 'Led Zeppelin', True)
# ('You Shook Me', 'Led Zeppelin', True)
# ('Your Time Is Gonna Come', 'Led Zeppelin', True)
# ('Do You Know What I Mean', 'Lee Michaels', True)
# ('Woman', 'Legs Diamond', True)
# ('American Woman', 'Lenny Kravitz', False)
# ('Are You Gonna Go My Way', 'Lenny Kravitz', False)
# ('Fly Away', 'Lenny Kravitz', False)
# ('Stranger In A Strange Land', 'Leon Russell', True)
# ('My Own Worst Enemy', 'Lit', False)
# ('Close My Eyes Forever', 'Lita Ford', False)
# ('Kiss Me Deadly', 'Lita Ford', False)
# ('All That You Dream', 'Little Feat', True)
# ('Dixie Chicken', 'Little Feat', False)
# ('I Alone', 'Live', True)
# ('Lightning Crashes', 'Live', False)
# ('Cult Of Personality', 'Living Colour', False)
# ('Bound for the Floor', 'Local H', False)
# ('Conquistador', 'London Symphony Orchestra', True)
# ('Midnight Blue', 'Lou Gramm', True)
# ('Sweet Jane (Live)', 'Lou Reed', False)
# ('Walk On The Wild Side', 'Lou Reed', False)
# ("Lovin' Every Minute of It", 'Loverboy', True)
# ('The Kid Is Hot Tonite', 'Loverboy', False)
# ('Turn Me Loose', 'Loverboy', False)
# ('Working for the Weekend', 'Loverboy', False)
# ('Wicked Sensation', 'Lynch Mob', True)
# ('Call Me the Breeze', 'Lynyrd Skynyrd', False)
# ('Dixie/Sweet Home Alabama', 'Lynyrd Skynyrd', False)
# ("Don't Ask Me No Questions", 'Lynyrd Skynyrd', False)
# ('Free Bird', 'Lynyrd Skynyrd', False)
# ('Gimme Back My Bullets', 'Lynyrd Skynyrd', False)
# ('Gimme Three Steps', 'Lynyrd Skynyrd', False)
# ('I Know a Little', 'Lynyrd Skynyrd', False)
# ('Saturday Night Special', 'Lynyrd Skynyrd', False)
# ('Simple Man', 'Lynyrd Skynyrd', False)
# ('Sweet Home Alabama', 'Lynyrd Skynyrd', False)
# ('That Smell', 'Lynyrd Skynyrd', False)
# ('The Ballad Of Curtis Loew', 'Lynyrd Skynyrd', False)
# ("Tuesday's Gone", 'Lynyrd Skynyrd', False)
# ("What's Your Name", 'Lynyrd Skynyrd', False)
# ('You Got That Right', 'Lynyrd Skynyrd', True)
# ('Merry-Go-Round', "Mama's Pride", True)
# ('Blinded by the Light', 'Manfred Mann', False)
# ('Do Wah Diddy Diddy', 'Manfred Mann', True)
# ('Sex and Candy', 'Marcy Playground', True)
# ('Paradise By The Dashboard Light', 'Meat Loaf', False)
# ("TWO OUT OF THREE AIN'T BAD", 'Meat Loaf', False)
# ('You Took The Words Right Out Of My Mouth', 'Meat Loaf', False)
# ("I'm the Only One", 'Melissa Etheridge', False)
# ('Down Under', 'Men At Work', False)
# ('Who Can It Be Now?', 'Men At Work', False)
# ('Breadfan', 'Metallica', False)
# ('Enter Sandman', 'Metallica', False)
# ('Fade To Black', 'Metallica', False)
# ('For Whom The Bell Tolls', 'Metallica', False)
# ('Fuel', 'Metallica', False)
# ('Harvester Of Sorrow', 'Metallica', False)
# ('Hero of the Day', 'Metallica', False)
# ('Lords of Summer (First Pass Version)', 'Metallica', True)
# ('Master of Puppets', 'Metallica', False)
# ('No Leaf Clover', 'Metallica', False)
# ('Nothing Else Matters', 'Metallica', False)
# ('One', 'Metallica', False)
# ('Sad But True', 'Metallica', False)
# ('Seek & Destroy', 'Metallica', False)
# ('The Memory Remains', 'Metallica', False)
# ('The Unforgiven', 'Metallica', False)
# ('Turn The Page', 'Metallica', True)
# ('Until It Sleeps', 'Metallica', False)
# ('Wherever I May Roam', 'Metallica', False)
# ('Whiskey In The Jar', 'Metallica', True)
# ("Cruisin'", 'Michael Nesmith', True)
# ...
# ('You Might Think', 'The Cars', False)
# ("You're All I've Got Tonight", 'The Cars', True)
# ('Clampdown', 'The Clash', False)
# ('I Fought The Law', 'The Clash', True)
# ('London Calling', 'The Clash', False)
# ('Rock The Casbah', 'The Clash', False)
# ('Should I Stay Or Should', 'The Clash', False)
# ('Train In Vain', 'The Clash', False)
# ('Fire Woman', 'The Cult', False)
# ('Another Park, Another Sunday', 'The Doobie Brothers', False)
# ('Black Water', 'The Doobie Brothers', False)
# ('China Grove', 'The Doobie Brothers', False)
# ("It Keeps You Runnin'", 'The Doobie Brothers', True)
# ('Jesus Is Just Alright', 'The Doobie Brothers', False)
# ('Listen To The Music', 'The Doobie Brothers', False)
# ("Livin' On the Fault Line", 'The Doobie Brothers', True)
# ("Long Train Runnin'", 'The Doobie Brothers', False)
# ('Natural Thing', 'The Doobie Brothers', True)
# ("Rockin' Down The Highway", 'The Doobie Brothers', False)
# ('South City Midnight Lady', 'The Doobie Brothers', True)
# ('Take Me In Your Arms', 'The Doobie Brothers', False)
# ("Takin' It To The Streets", 'The Doobie Brothers', False)
# ('UKIAH/THE CAPTAIN AND ME', 'The Doobie Brothers', True)
# ('What a Fool Believes', 'The Doobie Brothers', False)
# ('Wheels Of Fortune', 'The Doobie Brothers', True)
# ('Back Door Man', 'The Doors', True)
# ('Break On Through', 'The Doors', True)
# ('Five To One', 'The Doors', True)
# ('Gloria', 'The Doors', True)
# ('Hello, I Love You', 'The Doors', True)
# ('L.A. Woman', 'The Doors', False)
# ('Light My Fire', 'The Doors', True)
# ('Love Her Madly', 'The Doors', False)
# ('Love Me Two Times', 'The Doors', True)
# ('Moonlight Drive', 'The Doors', True)
# ('Peace Frog', 'The Doors', False)
# ('People Are Strange', 'The Doors', True)
# ('Riders On The Storm', 'The Doors', False)
# ('Roadhouse Blues', 'The Doors', True)
# ('Soul Kitchen', 'The Doors', True)
# ('The Changeling', 'The Doors', False)
# ('The Crystal Ship', 'The Doors', True)
# ('Touch Me', 'The Doors', True)
# ('Twentieth Century Fox', 'The Doors', True)
# ('Waiting For The Sun', 'The Doors', False)
# ("When the Music's Over", 'The Doors', True)
# ('Tuff Enuff', 'The Fabulous Thunderbirds', True)
# ('Radioactive', 'The Firm', False)
# ('One Thing Leads To Another', 'The Fixx', False)
# ('Saved By Zero', 'The Fixx', False)
# ('Iris', 'The Goo Goo Dolls', False)
# ('Funk #49', 'The James Gang', False)
# ('This Beat Goes on/Switching to Glide', 'The Kings', True)
# ('A Well Respected Man', 'The Kinks', True)
# ('All Day And All Of The Night', 'The Kinks', True)
# ('Apeman', 'The Kinks', False)
# ('Come Dancing', 'The Kinks', False)
# ('Destroyer', 'The Kinks', False)
# ('Lola', 'The Kinks', False)
# ('Sunny Afternoon', 'The Kinks', True)
# ('Superman', 'The Kinks', True)
# ('Tired of Waiting', 'The Kinks', True)
# ('Victoria', 'The Kinks', True)
# ('Waterloo Sunset', 'The Kinks', True)
# ('You Really Got Me', 'The Kinks', True)
# ('My Sharona', 'The Knack', False)
# ('Mrs. Robinson', 'The Lemonheads', True)
# ('Summer In the City', "The Lovin' Spoonful", True)
# ("CALIFORNIA DREAMIN'", 'The Mamas ', True)
# ("Can't You See", 'The Marshall Tucker Band', False)
# ('HEARD IT IN A LOVE SONG', 'The Marshall Tucker Band', False)
# ('Take The Highway', 'The Marshall Tucker Band', True)
# ('Gypsy', 'The Moody Blues', True)
# ('Question', 'The Moody Blues', False)
# ('Ride My See Saw', 'The Moody Blues', True)
# ('The Story In Your Eyes', 'The Moody Blues', False)
# ('Your Wildest Dreams', 'The Moody Blues', False)
# ('Life in the Fast Lane', 'The New Eagles', False)
# ('Come Out and Play', 'The Offspring', False)
# ('Self Esteem', 'The Offspring', False)
# ("The Kids Aren't Alright", 'The Offspring', False)
# ('Your Love', 'The Outfield', False)
# ('Green Grass & High Tides', 'The Outlaws', False)
# ("Can't Stand Losing You", 'The Police', False)
# ('De Do Do Do, De Da Da Da', 'The Police', False)
# ("Don't Stand So Close To Me", 'The Police', False)
# ('Driven to Tears', 'The Police', False)
# ('Every Breath You Take', 'The Police', False)
# ('Every Little Thing She Does Is Magic', 'The Police', False)
# ('Invisible Sun', 'The Police', False)
# ('King Of Pain', 'The Police', False)
# ('Message In A Bottle', 'The Police', False)
# ('Roxanne', 'The Police', False)
# ('So Lonely', 'The Police', False)
# ('Spirits In The Material World', 'The Police', False)
# ('Synchronicity II', 'The Police', False)
# ('Walking On The Moon', 'The Police', False)
# ('Wrapped Around Your Finger', 'The Police', False)
# ('Some Like It Hot', 'The Power Station', False)
# ('Back On The Chain Gang', 'The Pretenders', False)
# ('Brass In Pocket', 'The Pretenders', False)
# ("Don't Get Me Wrong", 'The Pretenders', False)
# ('Message of Love', 'The Pretenders', True)
# ('Middle Of The Road', 'The Pretenders', False)
# ('My City Was Gone', 'The Pretenders', False)
# ('Mystery Achievement', 'The Pretenders', True)
# ('TALK OF THE TOWN', 'The Pretenders', False)
# ('Blitzkrieg Bop', 'The Ramones', False)
# ("Do You Remember Rock 'n' Roll Radio", 'The Ramones', False)
# ('I Wanna Be Sedated', 'The Ramones', False)
# ("Rock 'n' Roll High School", 'The Ramones', True)
# ('Rockaway Beach', 'The Ramones', True)
# ('Teenage Lobotomy', 'The Ramones', True)
# ('TALKING IN YOUR SLEEP', 'The Romantics', False)
# ('What I Like About You', 'The Romantics', False)
# ('Itchycoo Park', 'The Small Faces', True)
# ('A Girl Like You', 'The Smithereens', False)
# ("I'm A Man", 'The Spencer Davis Group', True)
# ('Dirty Water', 'The Standells', True)
# ('End of the Line', 'The Traveling Wilburys', False)
# ('Handle with Care', 'The Traveling Wilburys', False)
# ('Tweeter and the Monkey Man', 'The Traveling Wilburys', True)
# ("She's a Beauty", 'The Tubes', False)
# ('Talk To Ya Later', 'The Tubes', False)
# ('One Headlight', 'The Wallflowers', False)
# ('Seven Nation Army', 'The White Stripes', False)
# ('5:15', 'The Who', False)
# ('ANOTHER TRICKY DAY', 'The Who', True)
# ('Athena', 'The Who', False)
# ("Baba O'Reilly", 'The Who', False)
# ('Bargain', 'The Who', False)
# ('Behind Blue Eyes', 'The Who', False)
# ('Eminence Front', 'The Who', False)
# ('Getting In Tune', 'The Who', True)
# ('Going Mobile', 'The Who', False)
# ('Happy Jack', 'The Who', True)
# ('I Can See For Miles', 'The Who', True)
# ("I CAN'T EXPLAIN", 'The Who', True)
# ("I'm Free", 'The Who', True)
# ('Join Together', 'The Who', False)
# ('Long Live Rock', 'The Who', False)
# ("Love Reign O'er Me", 'The Who', False)
# ('Magic Bus', 'The Who', True)
# ('My Generation', 'The Who', True)
# ('Pinball Wizard', 'The Who', True)
# ("Shakin' All Over", 'The Who', True)
# ('Squeeze Box', 'The Who', False)
# ('Substitute', 'The Who', True)
# ('Summertime Blues', 'The Who', True)
# ('The Kids Are Alright', 'The Who', True)
# ('The Real Me', 'The Who', False)
# ('THE SEEKER', 'The Who', False)
# ('THE SONG IS OVER', 'The Who', False)
# ("We're Not Gonna Take It", 'The Who', True)
# ('Who Are You', 'The Who', False)
# ("Won't Get Fooled Again", 'The Who', False)
# ('You Better You Bet', 'The Who', False)
# ('Get Together', 'The Youngbloods', False)
# ('Jailbreak', 'Thin Lizzy', False)
# ('The Boys Are Back In Town', 'Thin Lizzy', False)
# ('The Cowboy Song', 'Thin Lizzy', True)
# ('Semi-Charmed Life', 'Third Eye Blind', False)
# ('Something In the Air', 'Thunderclap Newman', True)
# ('Bang the Drum All Day', 'Todd Rundgren', False)
# ("Hello It's Me", 'Todd Rundgren', False)
# ('I Saw the Light', 'Todd Rundgren', False)
# ('We Gotta Get You a Woman', 'Todd Rundgren', False)
# ('Life Is a Highway', 'Tom Cochrane', False)
# ('A Face In The Crowd', 'Tom Petty & The Heartbreakers', True)
# ('A Woman In Love', 'Tom Petty & The Heartbreakers', False)
# ('American Dream Plan B', 'Tom Petty & The Heartbreakers', True)
# ('American Girl', 'Tom Petty & The Heartbreakers', False)
# ('Breakdown', 'Tom Petty & The Heartbreakers', False)
# ('Change of Heart', 'Tom Petty & The Heartbreakers', True)
# ("Don't Come Around Here No More", 'Tom Petty & The Heartbreakers', False)
# ("Don't Do Me Like That", 'Tom Petty & The Heartbreakers', False)
# ('Even the Losers', 'Tom Petty & The Heartbreakers', True)
# ("Fooled Again (I Don't Like It)", 'Tom Petty & The Heartbreakers', True)
# ("Free Fallin'", 'Tom Petty & The Heartbreakers', False)
# ('Here Comes My Girl', 'Tom Petty & The Heartbreakers', False)
# ('I Need to Know', 'Tom Petty & The Heartbreakers', True)
# ("I Won't Back Down", 'Tom Petty & The Heartbreakers', False)
# ('Into the Great Wide Open', 'Tom Petty & The Heartbreakers', True)
# ("Jammin' Me", 'Tom Petty & The Heartbreakers', False)
# ('Learning To Fly', 'Tom Petty & The Heartbreakers', False)
# ('Listen To Your Heart', 'Tom Petty & The Heartbreakers', True)
# ("Mary Jane's Last Dance", 'Tom Petty & The Heartbreakers', False)
# ('Refugee', 'Tom Petty & The Heartbreakers', False)
# ("Runnin' Down a Dream", 'Tom Petty & The Heartbreakers', False)
# ("Stop Draggin' My Heart Around", 'Tom Petty & The Heartbreakers', False)
# ('The Waiting', 'Tom Petty & The Heartbreakers', False)
# ('U Get Me High', 'Tom Petty & The Heartbreakers', True)
# ('Yer So Bad', 'Tom Petty & The Heartbreakers', True)
# ("You Don't Know How It Feels", 'Tom Petty & The Heartbreakers', False)
# ('You Get Me High', 'Tom Petty & The Heartbreakers', True)
# ('You Got Lucky', 'Tom Petty & The Heartbreakers', False)
# ('You Wreck Me', 'Tom Petty & The Heartbreakers', False)
# ('867-5309 / Jenny', 'Tommy Tutone', False)
# ('If You Could Only See', 'Tonic', True)
# ('AFRICA', 'Toto', False)
# ('Hold The Line', 'Toto', False)
# ('Dear Mr. Fantasy', 'Traffic', True)
# ('Empty Pages', 'Traffic', True)
# ('Medicated Goo', 'Traffic', True)
# ('Medusa', 'Trapeze', True)
# ('Fight The Good Fight', 'Triumph', True)
# ('Hold On', 'Triumph', False)
# ('I Can Survive', 'Triumph', True)
# ('Lay It On the Line', 'Triumph', True)
# ('Magic Power', 'Triumph', True)
# ('Happy Together', 'Turtles', True)
# ('I Wanna Rock', 'Twisted Sister', False)
# ("We're Not Gonna Take It", 'Twisted Sister', False)
# ('Angel Of Harlem', 'U2', False)
# ('Bad', 'U2', False)
# ('Beautiful Day', 'U2', False)
# ('Bullet the Blue Sky', 'U2', False)
# ('Desire', 'U2', False)
# ('Even Better Than the Real Thing', 'U2', False)
# ("I Still Haven't Found What I'm Looking For", 'U2', False)
# ('I Will Follow', 'U2', False)
# ('MLK/Pride', 'U2', False)
# ('Mysterious Ways', 'U2', False)
# ("New Year's Day", 'U2', False)
# ('One', 'U2', False)
# ('Pride (In the Name of Love)', 'U2', False)
# ('Sunday Bloody Sunday', 'U2', False)
# ('Sweetest Thing', 'U2', False)
# ('Vertigo', 'U2', False)
# ('When Love Comes to Town', 'U2', False)
# ('Where the Streets Have No Name', 'U2', False)
# ('With Or Without You', 'U2', False)
# ('Red Red Wine', 'UB40', False)
# ('Lights Out (Live)', 'UFO', False)
# ('Too Hot To Handle', 'UFO', True)
# ("Easy Livin'", 'Uriah Heep', True)
# ("Stealin'", 'Uriah Heep', False)
# ('The Wizard', 'Uriah Heep', False)
# ('(Oh) Pretty Woman', 'Van Halen', False)
# ('1984/jump', 'Van Halen', False)
# ("Ain't Talkin' 'bout Love", 'Van Halen', False)
# ('And the Cradle Will Rock...', 'Van Halen', False)
# ('Atomic Punk', 'Van Halen', True)
# ('Beautiful Girls', 'Van Halen', False)
# ('Best Of Both Worlds', 'Van Halen', True)
# ('Black And Blue', 'Van Halen', True)
# ('Dance the Night Away', 'Van Halen', False)
# ('Dancing In the Street', 'Van Halen', False)
# ('Dreams', 'Van Halen', False)
# ('Drop Dead Legs', 'Van Halen', True)
# ('Eruption - You Really Got Me', 'Van Halen', False)
# ('Everybody Wants Some!!', 'Van Halen', False)
# ('Feel Your Love Tonight', 'Van Halen', True)
# ('Feels So Good', 'Van Halen', True)
# ('Finish What Ya Started', 'Van Halen', True)
# ('Hot for Teacher', 'Van Halen', False)
# ("I'll Wait", 'Van Halen', True)
# ("I'm the One", 'Van Halen', False)
# ('Ice Cream Man', 'Van Halen', False)
# ('Intruder/ Pretty Woman', 'Van Halen', True)
# ("Jamie's Cryin'", 'Van Halen', False)
# ('Jump', 'Van Halen', False)
# ('Little Dreamer', 'Van Halen', True)
# ('Little Guitars', 'Van Halen', False)
# ('Love Walks In', 'Van Halen', False)
# ('Mean Street', 'Van Halen', True)
# ('Panama', 'Van Halen', False)
# ('Poundcake', 'Van Halen', False)
# ('PRETTY WOMAN', 'Van Halen', True)
# ('Right Now', 'Van Halen', False)
# ('Runaround', 'Van Halen', True)
# ("Runnin' with the Devil", 'Van Halen', False)
# ('Somebody Get Me A Doctor', 'Van Halen', True)
# ('Summer Nights', 'Van Halen', False)
# ('Take Your Whiskey Home', 'Van Halen', True)
# ('Top Jimmy', 'Van Halen', True)
# ('Top of the World', 'Van Halen', True)
# ('Unchained', 'Van Halen', False)
# ("When It's Love", 'Van Halen', False)
# ('Where Have All the Good Times Gone!', 'Van Halen', False)
# ("Why Can't This Be Love", 'Van Halen', False)
# ('You Really Got Me', 'Van Halen', False)
# ('And It Stoned Me', 'Van Morrison', True)
# ('BLUE MONEY', 'Van Morrison', True)
# ('Brown Eyed Girl', 'Van Morrison', True)
# ('CRAZY LOVE', 'Van Morrison', False)
# ('Domino', 'Van Morrison', False)
# ('Gloria', 'Van Morrison', True)
# ('Into The Mystic', 'Van Morrison', False)
# ('Jackie Wilson Said', 'Van Morrison', True)
# ('Moondance', 'Van Morrison', False)
# ('Wild Night', 'Van Morrison', False)
# ('Blister In the Sun', 'Violent Femmes', False)
# ('Edge of a Broken Heart', 'Vixen', True)
# ('Low Rider', 'War', False)
# ('Spill the Wine', 'War', False)
# ('The Cisco Kid', 'War', False)
# ("Why Can't We Be Friends", 'War', False)
# ('Cherry Pie', 'Warrant', False)
# ("Uncle Tom's Cabin", 'Warrant', True)
# ('Lawyers, Guns and Money', 'Warren Zevon', False)
# ('Werewolves of London', 'Warren Zevon', False)
# ('Buddy Holly', 'Weezer', False)
# ('Street Corner Serenade', 'Wet Willie', True)
# ('Wait', 'White Lion', True)
# ('Fool for Your Loving', 'Whitesnake', False)
# ('Here I Go Again', 'Whitesnake', False)
# ('Is This Love', 'Whitesnake', False)
# ('Slide It In', 'Whitesnake', False)
# ("Slow An' Easy", 'Whitesnake', True)
# ('Still of the Night', 'Whitesnake', True)
# ('Who Are You?', 'Why Not', True)
# ('PLAY THAT FUNKY MUSIC', 'Wild Cherry', False)
# ('Night Moves', 'Wildlife', True)
# ("We've Got Tonight", 'Wildlife', True)
# ("Can't Get Enough", 'Winger', True)
# ('Headed For A Heartbreak', 'Winger', True)
# ('Seventeen', 'Winger', True)
# ('Persephone', 'Wishbone Ash', False)
# ('Summertime Girls', 'Y&T', True)
# ('Changes', 'Yes', False)
# ("I've Seen All Good People", 'Yes', False)
# ('It Can Happen', 'Yes', False)
# ('Leave It', 'Yes', False)
# ('Long Distance Runaround', 'Yes', False)
# ('Owner of a Lonely Heart', 'Yes', False)
# ('Roundabout', 'Yes', False)
# ('Starship Trooper', 'Yes', False)
# ('Wonderous Stories', 'Yes', True)
# ('Yours Is No Disgrace', 'Yes', False)
# ('Tell Me What You Want', 'Zebra', True)
# ("Who's Behind The Door", 'Zebra', True)
# ('Time of the Season', 'Zombies', True)
# ('A Fool for Your Stockings', 'ZZ Top', True)
# ('Arrested For Driving While Blind', 'ZZ Top', False)
# ('Beer Drinkers & Hell Raisers', 'ZZ Top', False)
# ('Cheap Sunglasses', 'ZZ Top', False)
# ('Gimme All Your Lovin', 'ZZ Top', False)
# ('Got Me Under Pressure', 'ZZ Top', False)
# ('Heard It On the X', 'ZZ Top', False)
# ('I Thank You', 'ZZ Top', True)
# ("I'm Bad, I'm Nationwide", 'ZZ Top', True)
# ('Jesus Just Left Chicago', 'ZZ Top', False)
# ('Just Got Paid', 'ZZ Top', True)
# ('La Grange', 'ZZ Top', False)
# ('Legs', 'ZZ Top', False)
# ("My Head's In Mississippi", 'ZZ Top', True)
# ('Party On The Patio', 'ZZ Top', True)
# ('Pearl Necklace', 'ZZ Top', False)
# ('Sharp Dressed Man', 'ZZ Top', False)
# ('She Loves My Automobile', 'ZZ Top', True)
# ('Tube Snake Boogie', 'ZZ Top', False)
# ('Tush', 'ZZ Top', False)
# ('TV Dinners', 'ZZ Top', False)
# ("WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO", 'ZZ Top', False)
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 2200    None
# 2201    None
# 2202    None
# 2203    None
# 2204    None
# 2205    None
# 2206    None
# 2207    None
# 2208    None
# 2209    None
# 2210    None
# 2211    None
# 2212    None
# 2213    None
# 2214    None
# 2215    None
# 2216    None
# 2217    None
# 2218    None
# 2219    None
# 2220    None
# 2221    None
# 2222    None
# 2223    None
# 2224    None
# 2225    None
# 2226    None
# 2227    None
# 2228    None
# 2229    None
# Length: 2230, dtype: object

# %% [markdown]
# You'll notice that there will be a final output Series of `None` values. The `.apply()` function, if a return value is not specified, will return a Series of `None` values (similar to how the default return for Python functions is `None` when a return statement is not specified).

# %% [markdown]
# ### 9. Write a function that converts cells in a DataFrame to float and otherwise replaces them with `np.nan`.
#
# If applied to our data, it would keep only the numeric information and otherwise input null values.
#
# Recall that the try-except syntax in Python is a great way to try something and take another action if the initial step fails:
#
# ```python
# try:
#     Perform some action.
# except:
#    Perform some other action if the first failed with an error.
# ```
#
# #### 9.A Write the function that takes a column and converts all of its values to float if possible and `np.nan` otherwise. The return value should be the converted Series.

# %%
# A:

def float_or_nan(column):
    new_col = []
    for el in column:
        try:
            new_col.append(float(el))
        except:
            new_col.append(np.nan)
    return new_col

# %%
def element_converter(element):
    try:
        return float(element)
    except:
        return np.nan

def float_or_nan(column):
    return column.map(element_converter)

# %% [markdown]
# #### 9.B Try your function out on the rock song data and ensure the output is what you expected.

# %%
# A:

df.apply(float_or_nan)
# Out:
#       songclean  artistclean  releaseyear  combined  first  year  playcount  \
# 0           NaN          NaN       1982.0       NaN    1.0   1.0       82.0
# 1           NaN          NaN          0.0       NaN    1.0   0.0        3.0
# 2           NaN          NaN       1981.0       NaN    1.0   1.0       85.0
# 3           NaN          NaN       1980.0       NaN    1.0   1.0       18.0
# 4           NaN          NaN       1975.0       NaN    1.0   1.0        1.0
# 5           NaN          NaN       2000.0       NaN    1.0   1.0       13.0
# 6           NaN          NaN       2000.0       NaN    1.0   1.0        1.0
# 7           NaN          NaN       2002.0       NaN    1.0   1.0        6.0
# 8           NaN          NaN       1992.0       NaN    1.0   1.0        3.0
# 9           NaN          NaN       1985.0       NaN    1.0   1.0        1.0
# 10          NaN          NaN          0.0       NaN    1.0   0.0        1.0
# 11          NaN          NaN       1980.0       NaN    1.0   1.0       97.0
# 12          NaN          NaN       1993.0       NaN    1.0   1.0        6.0
# 13          NaN          NaN          0.0       NaN    1.0   0.0        5.0
# 14          NaN          NaN       1976.0       NaN    1.0   1.0       85.0
# 15          NaN          NaN       1981.0       NaN    1.0   1.0       46.0
# 16          NaN          NaN          0.0       NaN    1.0   0.0       24.0
# 17          NaN          NaN       1995.0       NaN    1.0   1.0        1.0
# 18          NaN          NaN       1980.0       NaN    1.0   1.0       39.0
# 19          NaN          NaN       1980.0       NaN    1.0   1.0       74.0
# 20          NaN          NaN       1979.0       NaN    1.0   1.0       92.0
# 21          NaN          NaN       1975.0       NaN    1.0   1.0       39.0
# 22          NaN          NaN       1984.0       NaN    1.0   1.0        1.0
# 23          NaN          NaN       1977.0       NaN    1.0   1.0        3.0
# 24          NaN          NaN          0.0       NaN    1.0   0.0        4.0
# 25          NaN          NaN          0.0       NaN    1.0   0.0        2.0
# 26          NaN          NaN          0.0       NaN    1.0   0.0       20.0
# 27          NaN          NaN       1979.0       NaN    1.0   1.0        1.0
# 28          NaN          NaN       1980.0       NaN    1.0   1.0       21.0
# 29          NaN          NaN          0.0       NaN    1.0   0.0       45.0
# ...         ...          ...          ...       ...    ...   ...        ...
# 2200        NaN          NaN       1983.0       NaN    1.0   1.0       81.0
# 2201        NaN          NaN       1971.0       NaN    1.0   1.0       44.0
# 2202        NaN          NaN       1971.0       NaN    1.0   1.0        1.0
# 2203        NaN          NaN          0.0       NaN    1.0   0.0        5.0
# 2204        NaN          NaN       1971.0       NaN    1.0   1.0        1.0
# 2205        NaN          NaN          0.0       NaN    1.0   0.0        2.0
# 2206        NaN          NaN          0.0       NaN    1.0   0.0        1.0
# 2207        NaN          NaN       1968.0       NaN    1.0   1.0       14.0
# 2208        NaN          NaN          0.0       NaN    1.0   0.0        1.0
# 2209        NaN          NaN       1976.0       NaN    1.0   1.0        1.0
# 2210        NaN          NaN       1973.0       NaN    1.0   1.0        8.0
# 2211        NaN          NaN       1980.0       NaN    1.0   1.0       34.0
# 2212        NaN          NaN       1983.0       NaN    1.0   1.0       86.0
# 2213        NaN          NaN       1983.0       NaN    1.0   1.0       29.0
# 2214        NaN          NaN       1975.0       NaN    1.0   1.0        2.0
# 2215        NaN          NaN          0.0       NaN    1.0   0.0       16.0
# 2216        NaN          NaN          0.0       NaN    1.0   0.0       10.0
# 2217        NaN          NaN       1973.0       NaN    1.0   1.0        6.0
# 2218        NaN          NaN          0.0       NaN    1.0   0.0        2.0
# 2219        NaN          NaN       1973.0       NaN    1.0   1.0      111.0
# 2220        NaN          NaN       1983.0       NaN    1.0   1.0      121.0
# 2221        NaN          NaN          0.0       NaN    1.0   0.0        1.0
# 2222        NaN          NaN          0.0       NaN    1.0   0.0       14.0
# 2223        NaN          NaN       1981.0       NaN    1.0   1.0        5.0
# 2224        NaN          NaN       1983.0       NaN    1.0   1.0      120.0
# 2225        NaN          NaN          0.0       NaN    1.0   0.0        1.0
# 2226        NaN          NaN       1981.0       NaN    1.0   1.0       32.0
# 2227        NaN          NaN       1975.0       NaN    1.0   1.0      109.0
# 2228        NaN          NaN       1983.0       NaN    1.0   1.0        1.0
# 2229        NaN          NaN       1973.0       NaN    1.0   1.0        2.0
#
#          fg
# 0      82.0
# 1       0.0
# 2      85.0
# 3      18.0
# 4       1.0
# 5      13.0
# 6       1.0
# 7       6.0
# 8       3.0
# 9       1.0
# 10      0.0
# 11     97.0
# 12      6.0
# 13      0.0
# 14     85.0
# 15     46.0
# 16      0.0
# 17      1.0
# 18     39.0
# 19     74.0
# 20     92.0
# 21     39.0
# 22      1.0
# 23      3.0
# 24      0.0
# 25      0.0
# 26      0.0
# 27      1.0
# 28     21.0
# 29      0.0
# ...     ...
# 2200   81.0
# 2201   44.0
# 2202    1.0
# 2203    0.0
# 2204    1.0
# 2205    0.0
# 2206    0.0
# 2207   14.0
# 2208    0.0
# 2209    1.0
# 2210    8.0
# 2211   34.0
# 2212   86.0
# 2213   29.0
# 2214    2.0
# 2215    0.0
# 2216    0.0
# 2217    6.0
# 2218    0.0
# 2219  111.0
# 2220  121.0
# 2221    0.0
# 2222    0.0
# 2223    5.0
# 2224  120.0
# 2225    0.0
# 2226   32.0
# 2227  109.0
# 2228    1.0
# 2229    2.0
#
# [2230 rows x 8 columns]

# %% [markdown]
# #### 9.C Describe the new float-only DataFrame.

# %%
df.apply(float_or_nan).describe()
# Out:
#          songclean  artistclean  releaseyear  combined   first         year  \
# count     2.000000          0.0  2229.000000       0.0  2230.0  2230.000000
# mean   1012.000000          NaN  1465.988784       NaN     1.0     0.741256
# std    1367.544515          NaN   866.834789       NaN     0.0     0.438043
# min      45.000000          NaN     0.000000       NaN     1.0     0.000000
# 25%     528.500000          NaN     0.000000       NaN     1.0     0.000000
# 50%    1012.000000          NaN  1973.000000       NaN     1.0     1.000000
# 75%    1495.500000          NaN  1981.000000       NaN     1.0     1.000000
# max    1979.000000          NaN  2014.000000       NaN     1.0     1.000000
#
#          playcount           fg
# count  2230.000000  2230.000000
# mean     16.872646    15.048430
# std      25.302972    25.288366
# min       0.000000     0.000000
# 25%       1.000000     0.000000
# 50%       4.000000     3.000000
# 75%      21.000000    18.000000
# max     142.000000   142.000000

# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Practice SQL with `pandas`, Pt. 2
#
#
# ---
#
# We've learned about relational databases and the language most use to query them: SQL.
#
# In this lab, we are going to get more practice converting information to a SQL database, querying that data, and then analyzing it with Python.

# %%
# Necessary libraries:
import pandas as pd
import sqlite3
from pandas.io import sql

# %% [markdown]
# #### 1.  Read in the `EuroMart` `.csv` data.
# - 'EuroMart-ListOfOrders.csv'
# - 'EuroMart-OrderBreakdown.csv'
# - 'EuroMart-SalesTargets.csv'

# %%
# Reading in the `.csv` to a DataFrame:
orders = pd.read_csv('./datasets/csv/EuroMart-ListOfOrders.csv', encoding = 'utf-8')
OBD =  pd.read_csv('./datasets/csv/EuroMart-OrderBreakdown.csv', encoding = 'utf-8')
sales_targets =  pd.read_csv('./datasets/csv/EuroMart-SalesTargets.csv', encoding = 'utf-8')

# %% [markdown]
# #### 2. Rename columns to remove any spaces.

# %%
orders.columns = [col.replace(' ', '') for col in orders.columns]
OBD.columns = [col.replace(' ', '') for col in OBD.columns]
sales_targets.columns = [col.replace(' ', '') for col in sales_targets.columns]

# %% [markdown]
# #### 3. Remove dollar signs from the `sales` and `profit` columns in the `order breakdown` DataFrame.
#
# Convert the columns to float.

# %%
OBD['Sales'] = [e.replace('$', '') for e in OBD['Sales']]
OBD['Profit'] = [e.replace('$', '') for e in OBD['Profit']]
OBD.head()
# Out:
#            OrderID                            ProductName  Discount   Sales  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5   45.00
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0  854.00
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0  140.00
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5   27.00
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5   17.00
#
#    Profit  Quantity         Category Sub-Category
# 0  -26.00         3  Office Supplies        Paper
# 1  290.00         7        Furniture    Bookcases
# 2   21.00         3  Office Supplies          Art
# 3  -22.00         2  Office Supplies          Art
# 4   -1.00         2  Office Supplies      Storage

# %% [markdown]
# #### 4. Create a SQL database called `EuroMart` and save the three DataFrames as SQL tables.

# %%
# Establishing a local DB connection:
db_connection = sqlite3.connect('./datasets/sql/2.db.sqlite')

# %%
orders.to_sql(name = 'orders', con = db_connection, if_exists = 'replace', index = False)
OBD.to_sql(name = 'OBD', con = db_connection, if_exists = 'replace', index = False)
sales_targets.to_sql(name = 'sales_targets', con = db_connection, if_exists = 'replace', index = False)

# %% [markdown]
# #### 5. How many orders has each customer placed?

# %%
def q(query, connection=db_connection):
    return sql.read_sql(query, connection)

# %%
q("""SELECT * FROM orders LIMIT 1
""")
# Out:
#            OrderID OrderDate CustomerName       City Country Region  \
# 0  BN-2011-7407039  1/1/2011   Ruby Patel  Stockholm  Sweden  North
#
#        Segment  ShipDate      ShipMode      State
# 0  Home Office  1/5/2011  Economy Plus  Stockholm

# %%
q("""SELECT "CustomerName", COUNT("CustomerName") AS order_no
    FROM orders 
    GROUP BY "CustomerName"
    ORDER BY COUNT("CustomerName") DESC
    LIMIT 5
""")
# Out:
#       CustomerName  order_no
# 0     Jose Gambino        13
# 1     Kayla Tearle        12
# 2  Mark Washington        12
# 3    Aaron Bootman        11
# 4  Georgina Garner        11

# %% [markdown]
# > *If you're doubting your output, check using `pandas`.*

# %% [markdown]
# #### 6. Create a query to return a table containing only geographic features from the `list of orders` table.

# %%
q("""SELECT "City", "Country", "Region", "State"
    FROM orders
    GROUP BY "City", "Country", "Region", "State"
    LIMIT 5
""")
# Out:
#         City         Country   Region                        State
# 0     Aachen         Germany  Central       North Rhine-Westphalia
# 1      Aalen         Germany  Central            Baden-Württemberg
# 2      Aalst         Belgium  Central                East Flanders
# 3  Abbeville          France  Central  Nord-Pas-de-Calais-Picardie
# 4   Aberdeen  United Kingdom    North                     Scotland

# %% [markdown]
# #### 7. Create a query to return a table containing all orders that had a negative profit from the `order breakdown` table.

# %%
q("""SELECT * FROM OBD LIMIT 1
""")
# Out:
#            OrderID                  ProductName  Discount  Sales  Profit  \
# 0  BN-2011-7407039  Enermax Note Cards, Premium       0.5  45.00  -26.00
#
#    Quantity         Category Sub-Category
# 0         3  Office Supplies        Paper

# %%
q("""SELECT * 
    FROM OBD 
    WHERE "Profit" < 0
    LIMIT 5
""")
# Out:
#            OrderID                      ProductName  Discount   Sales  \
# 0  BN-2011-7407039      Enermax Note Cards, Premium       0.5   45.00
# 1  BN-2011-2819714       Boston Markers, Easy-Erase       0.5   27.00
# 2  BN-2011-2819714      Eldon Folders, Single Width       0.5   17.00
# 3  BN-2011-3248724     Ikea Classic Bookcase, Metal       0.6  987.00
# 4  BN-2011-3248724  Binney & Smith Sketch Pad, Blue       0.5  116.00
#
#       Profit  Quantity         Category Sub-Category
# 0     -26.00         3  Office Supplies        Paper
# 1     -22.00         2  Office Supplies          Art
# 2      -1.00         2  Office Supplies      Storage
# 3  -1,012.00         6        Furniture    Bookcases
# 4     -56.00         5  Office Supplies          Art

# %% [markdown]
# #### 8. Construct a query to return a table containing `customer_name` and `product_name`.
#
# > **Note:** This will require a JOIN!

# %%
q("""SELECT a."CustomerName", a."OrderID", b."ProductName"
    FROM orders AS a
    LEFT JOIN OBD AS b
    ON a."OrderID" = b."OrderID"
    GROUP BY a."CustomerName", a."OrderID", b."ProductName"
    LIMIT 10
""")
# Out:
#     CustomerName          OrderID  \
# 0  Aaron Bootman  AZ-2011-2169445
# 1  Aaron Bootman  AZ-2011-2169445
# 2  Aaron Bootman  AZ-2011-2169445
# 3  Aaron Bootman  AZ-2011-3937280
# 4  Aaron Bootman  AZ-2011-3937280
# 5  Aaron Bootman  AZ-2011-9409671
# 6  Aaron Bootman  AZ-2011-9409671
# 7  Aaron Bootman   AZ-2012-808163
# 8  Aaron Bootman  AZ-2012-9056595
# 9  Aaron Bootman  AZ-2012-9056595
#
#                                          ProductName
# 0                   Apple Office Telephone, Cordless
# 1                       Elite Box Cutter, High Speed
# 2  Harbour Creations Round Labels, Laser Printer ...
# 3                    Elite Letter Opener, High Speed
# 4                         Tenex Light Bulb, Duo Pack
# 5                Binney & Smith Markers, Fluorescent
# 6              Novimex Shipping Labels, Alphabetical
# 7                    Konica Receipt Printer, Durable
# 8                      Office Star Bag Chairs, Black
# 9                        Okidata Calculator, Durable

# %% [markdown]
# #### 9.  How many orders for "office supplies" (category) has Sweden made?
#
# > **Note:** From this point on, you'll probably be combining SQL and `pandas`, in that you would use SQL queries to gather relevant information and then `pandas` to analyze it.

# %%
ordersdf = q("""SELECT * FROM orders
""")

# %%
ordersdf[ordersdf['Country'] == 'Sweden'].groupby('Segment').size()
# Out:
# Segment
# Consumer       45
# Corporate      39
# Home Office    16
# dtype: int64

# %% [markdown]
# #### 10. What were total sales for discontinued products?

# %%
q("""SELECT * FROM orders LIMIT 1
""")
# Out:
#            OrderID OrderDate CustomerName       City Country Region  \
# 0  BN-2011-7407039  1/1/2011   Ruby Patel  Stockholm  Sweden  North
#
#        Segment  ShipDate      ShipMode      State
# 0  Home Office  1/5/2011  Economy Plus  Stockholm

# %%
q("""SELECT "CustomerName", CAST(EXTRACT('year' FROM "OrderDate") AS Int) AS "year"
    FROM orders
""")
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-93-0f25d67d326d> in <module>()
#       4         CAST(EXTRACT('day' FROM "OrderDate") AS Int) AS "day"
#       5         FROM orders
# ----> 6 """)
#
# <ipython-input-27-0094a9b35db0> in q(query, connection)
#       1 def q(query, connection=db_connection):
# ----> 2     return sql.read_sql(query, connection)
#
# C:\Users\Samson\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\io\sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     398             sql, index_col=index_col, params=params,
#     399             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 400             chunksize=chunksize)
#     401
#     402     try:
#
# C:\Users\Samson\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\io\sql.pyc in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1442
#    1443         args = _convert_params(sql, params)
# -> 1444         cursor = self.execute(*args)
#    1445         columns = [col_desc[0] for col_desc in cursor.description]
#    1446
#
# C:\Users\Samson\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\io\sql.pyc in execute(self, *args, **kwargs)
#    1419             ex = DatabaseError(
#    1420                 "Execution failed on sql '%s': %s" % (args[0], exc))
# -> 1421             raise_with_traceback(ex)
#    1422
#    1423     @staticmethod
#
# C:\Users\Samson\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\io\sql.pyc in execute(self, *args, **kwargs)
#    1407                 cur.execute(*args, **kwargs)
#    1408             else:
# -> 1409                 cur.execute(*args)
#    1410             return cur
#    1411         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'SELECT "OrderDate", "Freight",
#         CAST(EXTRACT('year' FROM "OrderDate") AS Int) AS "year",
#         CAST(EXTRACT('month' FROM "OrderDate") AS Int) AS "month",
#         CAST(EXTRACT('day' FROM "OrderDate") AS Int) AS "day"
#         FROM orders
# ': near "FROM": syntax error

# %% [markdown]
# #### 11. What is the total quantity of objects sold for each country?

# %%
ordersdf.groupby('Country').size()
# Out:
# Country
# Austria           135
# Belgium            68
# Denmark            29
# Finland            34
# France            991
# Germany           806
# Ireland            50
# Italy             493
# Netherlands       194
# Norway             37
# Portugal           37
# Spain             403
# Sweden            100
# Switzerland        40
# United Kingdom    700
# dtype: int64

# %% [markdown]
# #### 12. In what countries were profits lowest? (Report the lowest 5-10).

# %%
combine = q("""SELECT a.*, b.* 
            FROM orders AS a
            LEFT JOIN OBD AS b
            ON a."OrderID"=b."OrderID" """)

# %%
combine['Profit'] = [float(cell.replace(',', '')) for cell in combine['Profit']]
combine['Sales'] = [float(cell.replace(',', '')) for cell in combine['Sales']]

# %%
combine.groupby('Country').mean().sort_values('Profit')
# Out:
#                 Discount       Sales      Profit  Quantity
# Country
# Portugal        0.500000  215.800000 -124.342857  4.085714
# Netherlands     0.480662  178.913486  -94.625954  3.882952
# Sweden          0.507882  150.197044  -86.325123  3.709360
# Ireland         0.503000  159.980000  -68.860000  3.920000
# Denmark         0.508333  129.383333  -60.133333  3.400000
# Italy           0.125230  258.163432   16.140960  3.689479
# France          0.076722  318.206159   36.569415  3.825157
# Germany         0.054787  297.976220   52.609146  3.767683
# Finland         0.000000  323.468750   61.062500  3.140625
# Spain           0.034297  327.729304   61.848883  3.785808
# United Kingdom  0.070167  320.012938   68.783866  3.742009
# Belgium         0.000000  313.481481   73.422222  3.940741
# Norway          0.000000  293.271429   73.814286  3.728571
# Austria         0.000000  300.689394   80.803030  3.685606
# Switzerland     0.000000  318.897436   92.743590  3.948718

# %% [markdown]
# #### 13. What counties have the best and worst sales-to-profit ratios?
# (Total sales divided by total profits).
#
# Essentially, this is asking us to determine the profit made for every dollar of product sold.

# %%
combine['salestoprofit'] = combine['Sales']/combine['Profit']

# %%
combine[combine['salestoprofit'] != np.inf].groupby('Country').mean()
# Out:
#                 Discount       Sales      Profit  Quantity  salestoprofit
# Country
# Austria         0.000000  306.612403   82.682171  3.709302       8.597267
# Belgium         0.000000  314.454545   75.090909  3.916667       8.005054
# Denmark         0.508475  130.305085  -61.152542  3.406780      -5.550969
# Finland         0.000000  326.126984   62.031746  3.142857      10.723186
# France          0.077204  320.920498   37.894538  3.842077       4.274455
# Germany         0.054622  298.467208   53.890693  3.777014       5.763112
# Ireland         0.503125  162.114583  -71.729167  3.864583      -4.077488
# Italy           0.126702  258.604188   16.546597  3.693194       4.478296
# Netherlands     0.480739  182.379947  -98.121372  3.868074      -3.236133
# Norway          0.000000  296.373134   77.119403  3.791045       7.447800
# Portugal        0.500000  220.558824 -128.000000  4.132353      -3.228355
# Spain           0.034871  331.773406   63.862958  3.793758       4.587896
# Sweden          0.508122  152.543147  -88.954315  3.736041      -3.923878
# Switzerland     0.000000  326.197368   95.184211  3.960526      10.943289
# United Kingdom  0.070188  324.756651   70.721440  3.758998       6.021284

# %% [markdown]
# #### 14. What shipping method is most commonly used for "bookcases" (sub-category)?

# %%
combine[combine['Sub-Category']=='Bookcases'].groupby('ShipMode').size()
# Out:
# ShipMode
# Economy         234
# Economy Plus     76
# Immediate        22
# Priority         59
# dtype: int64

# %% [markdown]
# #### 15. Which city in the `orders` table generated the highest net sales? (List all cities and countries in descending order by net sales).

# %%
combine.groupby('City').sum().sort_values('Sales', ascending=False)
# Out:
#                          Discount    Sales   Profit  Quantity  salestoprofit
# City
# London                      24.30  69230.0  13931.0       820            inf
# Berlin                      23.50  52555.0   5942.0       690            inf
# Vienna                       0.00  51844.0  13207.0       714            inf
# Madrid                       4.10  44981.0  11129.0       580            inf
# Paris                        6.20  42245.0   6680.0       496            inf
# Rome                        13.90  28330.0    191.0       409            inf
# Barcelona                    2.80  27405.0   2246.0       231            inf
# Hamburg                      1.70  23574.0   5858.0       385            inf
# Marseille                    3.35  21677.0   2889.0       283            inf
# Turin                        7.70  19829.0   1937.0       236            inf
# Milan                       11.90  18837.0    233.0       291            inf
# Munich                       1.80  18429.0   3463.0       224            inf
# Edinburgh                    0.60  18016.0   5173.0       175            inf
# Stockholm                   63.00  17498.0 -11633.0       429            inf
# Bremen                       1.20  15342.0   3795.0       179            inf
# Bochum                       0.90  15144.0   3295.0       112            inf
# Valencia                     1.20  14958.0   3055.0       162            inf
# Frankfurt                    1.00  14640.0   2982.0       162            inf
# Lille                        1.05  14102.0    827.0       105     183.845312
# Cologne                      0.90  13301.0   2891.0       154     460.624283
# Nice                         2.25  13229.0   3012.0       147     106.496334
# Dortmund                     1.20  12724.0    526.0       121      96.145309
# Leipzig                      1.05  12380.0   2034.0        96     120.629065
# Leeds                        0.00  11884.0   2978.0       113            inf
# Toulouse                    31.85  11565.0  -9675.0       229            inf
# Krefeld                      0.40  11410.0   2381.0        87     226.743324
# Naples                       9.20  11388.0  -1140.0       162            inf
# Essen                        1.30  11211.0   2633.0       151            inf
# Dublin                      38.80  11071.0  -4681.0       300            inf
# Valladolid                   0.80  10938.0     58.0       102      89.431149
# ...                           ...      ...      ...       ...            ...
# Montigny-le-Bretonneux       0.00     36.0     12.0         2       3.000000
# Lagny-sur-Marne              0.00     35.0      5.0         2       7.000000
# Randers                      1.10     34.0    -29.0         3      -2.594737
# Estepona                     0.00     34.0     12.0         2       2.833333
# Torremolinos                 0.00     33.0     10.0         3       3.300000
# Saint-Jean-de-la-Ruelle      0.10     31.0     -2.0         2     -15.500000
# La Crau                      0.00     31.0     11.0         3       2.818182
# Castellammare di Stabia      0.60     30.0    -35.0         1      -0.857143
# Odivelas                     0.50     29.0    -22.0         2      -1.318182
# Cluses                       0.00     28.0     14.0         4       2.000000
# Vigevano                     0.00     28.0      6.0         4       4.666667
# Oss                          0.50     27.0    -25.0         2      -1.080000
# Morley                       0.00     27.0      6.0         3       4.500000
# Givors                       0.00     26.0     10.0         3       2.600000
# Massa                        0.00     26.0      8.0         2       3.250000
# Falconara Marittima          0.00     26.0      7.0         1       3.714286
# Viroflay                     0.00     26.0     11.0         2       2.363636
# Andria                       0.00     26.0      9.0         2       2.888889
# Manfredonia                  0.40     25.0     -5.0         4      -5.000000
# Illkirch-Graffenstaden       0.10     24.0      8.0         1       3.000000
# Cestas                       0.00     23.0      6.0         2       3.833333
# Ragusa                       0.00     22.0      7.0         3       3.142857
# Battipaglia                  0.60     22.0    -20.0         1      -1.100000
# Millau                       0.00     21.0      5.0         2       4.200000
# Leiden                       0.50     19.0    -15.0         3      -1.266667
# Friedberg                    0.00     18.0      6.0         3       3.000000
# Sorgues                      0.00     14.0      3.0         2       4.666667
# Sète                         0.00     14.0      7.0         3       2.000000
# Aix-les-Bains                0.00     10.0      4.0         1       2.500000
# Osny                         0.00      5.0      2.0         1       2.500000
#
# [999 rows x 5 columns]

# %% [markdown]
# ####  BONUS: Create a column called `shipping_delay` in the `orders` table that contains the difference in days between `order_date` and `ship_date`.

# %%
combine['shipping_delay'] = pd.to_datetime(combine['ShipDate']) - pd.to_datetime(combine['OrderDate'])
combine['shipping_delay'] = combine['shipping_delay'].apply(lambda x: x.days)

# %%
combine.head()
# Out:
#            OrderID OrderDate      CustomerName        City         Country  \
# 0  BN-2011-7407039  1/1/2011        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313  1/3/2011    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300  1/4/2011  Devin Huddleston     Valence          France
# 3  BN-2011-2819714  1/4/2011       Mary Parker  Birmingham  United Kingdom
# 4  BN-2011-2819714  1/4/2011       Mary Parker  Birmingham  United Kingdom
#
#     Region      Segment  ShipDate      ShipMode                 State  \
# 0    North  Home Office  1/5/2011  Economy Plus             Stockholm
# 1    North     Consumer  1/7/2011       Economy               England
# 2  Central     Consumer  1/8/2011       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate  1/9/2011       Economy               England
# 4    North    Corporate  1/9/2011       Economy               England
#
#            OrderID                            ProductName  Discount  Sales  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5   45.0
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0  854.0
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0  140.0
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5   27.0
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5   17.0
#
#    Profit  Quantity         Category Sub-Category  salestoprofit  \
# 0   -26.0         3  Office Supplies        Paper      -1.730769
# 1   290.0         7        Furniture    Bookcases       2.944828
# 2    21.0         3  Office Supplies          Art       6.666667
# 3   -22.0         2  Office Supplies          Art      -1.227273
# 4    -1.0         2  Office Supplies      Storage     -17.000000
#
#    shipping_delay
# 0               4
# 1               4
# 2               4
# 3               5
# 4               5

# %% [markdown]
# #### BONUS: Update your `orders` table in your SQLite3 DB to include the `shipping_delay` feature.

# %%
# A:

# %% [markdown]
# #### BONUS: Which product category has the highest average `shipping_delay`?

# %%
# A:

# %% [markdown]
# ### Challenge
#
# **In which months and categories were sales targets exceeded?**
#
# ---
#
# This may require a considerable amount of data processing.

# %%
# A:

# %%
import numpy as np
import scipy.stats as stats
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pprint

# this line tells jupyter notebook to put the plots in the notebook rather than saving them to file.
# %matplotlib inline

# this line makes plots prettier on mac retina screens. If you don't have one it shouldn't do anything.
# %config InlineBackend.figure_format = 'retina'

# %%
import sklearn

# %%
df.plot.scatter('x', 'y')

# %%
import sklearn.linear_model
import numpy as np

# %%
x = [52484.0, 49309.0, 53238.0, 57615.0, 48829.0, 48829.0, 57896.0, 53837.0, 47653.0, 52713.0, 47683.0, 47671.0, 51210.0, 40434.0, 41375.0, 47189.0, 44936.0, 51571.0, 45460.0]
y = [570048.0, 541233.0, 571317.0, 614188.0, 546415.0, 551852.0, 628240.0, 598405.0, 530146.0, 570679.0, 530444.0, 542090.0, 561742.0, 469986.0, 437553.0, 530109.0, 500230.0, 562720.0, 505518.0]
x_topredict = 42938.0

# %%
x = np.array(x).reshape(-1, 1)
y = np.array(y).reshape(-1, 1)

# %%
np.array(x).reshape()

# %%
lr = sklearn.linear_model.LinearRegression().fit(x, y)

# %%
lr.predict(x_topredict)
# Out:
# array([[482621.48299242]])

# %%
y = np.append(y, lr.predict(x_topredict))

# %%
x = np.append(x, x_topredict)

# %%
sns.regplot(x, y)
